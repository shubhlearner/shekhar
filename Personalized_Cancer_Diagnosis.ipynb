# %% [markdown]
# <br/>
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>
# <br/>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
import seaborn as sns
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, normalized_mutual_info_score
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold

import math
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data_variants = pd.read_csv('training_variants')
print('Number of data points : ', data_variants.shape[0])
print('Number of features : ', data_variants.shape[1])
print('Features : ', data_variants.columns.values)
data_variants.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
# Text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 49.72980000000007 seconds

# %%
# Merging both gene_variations and text data based on ID
result = pd.merge(data_variants, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
result.Gene = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')
y_true = result[['Class']]
x_true = result.drop(['Class'], axis=1)


print("Feature columns in dataset: ")
print(x_true.head())
print()
print("Target columns in dataset: ")
print(y_true.head())
# Out:
# Feature columns in dataset:
#    ID    Gene             Variation  \
# 0   0  FAM58A  Truncating_Mutations
# 1   1     CBL                 W802*
# 2   2     CBL                 Q249E
# 3   3     CBL                 N454D
# 4   4     CBL                 L399V
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...
#
# Target columns in dataset:
#    Class
# 0      1
# 1      2
# 2      2
# 3      3
# 4      4

# %%
# Split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
x_train, x_test, y_train, y_test = train_test_split(x_true, y_true, stratify=y_true, test_size=0.3)

# Split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
x_train, x_cv, y_train, y_cv = train_test_split(x_train, y_train, stratify=y_train, test_size=0.3)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', x_train.shape[0])
print('Number of data points in test data:', x_test.shape[0])
print('Number of data points in cross validation data:', x_cv.shape[0])
# Out:
# Number of data points in train data: 1626
# Number of data points in test data: 997
# Number of data points in cross validation data: 698

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
def plot_distribution(class_distribution,title,xlabel,ylabel):
    class_distribution.plot(kind='bar')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid()
    plt.show()


# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = y_train['Class'].value_counts().sort_values()
test_class_distribution = y_test['Class'].value_counts().sort_values()
cv_class_distribution = y_cv['Class'].value_counts().sort_values()

plot_distribution(train_class_distribution,
                 'Distribution of yi in train data',
                 'Class',
                 'Data points per Class')

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], 
          '(', np.round((train_class_distribution.values[i]/x_train.shape[0]*100), 3), '%)')
    
print('-'*80)



plot_distribution(test_class_distribution,
                 'Distribution of yi in test data',
                 'Class',
                 'Data points per Class')

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(test_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], 
          '(', np.round((test_class_distribution.values[i]/x_test.shape[0]*100), 3), '%)')

print('-'*80)



plot_distribution(cv_class_distribution,
                 'Distribution of yi in cross validation data',
                 'Class',
                 'Data points per Class')

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(cv_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-cv_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], 
          '(', np.round((cv_class_distribution.values[i]/x_cv.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 9 : 467 ( 28.721 %)
# Number of data points in class 8 : 336 ( 20.664 %)
# Number of data points in class 7 : 279 ( 17.159 %)
# Number of data points in class 6 : 221 ( 13.592 %)
# Number of data points in class 5 : 135 ( 8.303 %)
# Number of data points in class 4 : 118 ( 7.257 %)
# Number of data points in class 3 : 43 ( 2.645 %)
# Number of data points in class 2 : 18 ( 1.107 %)
# Number of data points in class 1 : 9 ( 0.554 %)
# --------------------------------------------------------------------------------
# Number of data points in class 9 : 286 ( 28.686 %)
# Number of data points in class 8 : 206 ( 20.662 %)
# Number of data points in class 7 : 170 ( 17.051 %)
# Number of data points in class 6 : 136 ( 13.641 %)
# Number of data points in class 5 : 82 ( 8.225 %)
# Number of data points in class 4 : 73 ( 7.322 %)
# Number of data points in class 3 : 27 ( 2.708 %)
# Number of data points in class 2 : 11 ( 1.103 %)
# Number of data points in class 1 : 6 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 9 : 200 ( 28.653 %)
# Number of data points in class 8 : 144 ( 20.63 %)
# Number of data points in class 7 : 119 ( 17.049 %)
# Number of data points in class 6 : 95 ( 13.61 %)
# Number of data points in class 5 : 58 ( 8.309 %)
# Number of data points in class 4 : 51 ( 7.307 %)
# Number of data points in class 3 : 19 ( 2.722 %)
# Number of data points in class 2 : 8 ( 1.146 %)
# Number of data points in class 1 : 4 ( 0.573 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the '9' class probabilites randomly such that they sum to 1. </p>

# %%
def plot_matrix(matrix,labels):
    plt.figure(figsize=(20,7))    
    sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    cm = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    recall_table =(((cm.T)/(cm.sum(axis=1))).T)
    # How did we calculateed recall_table :
    # divide each element of the confusion matrix with the sum of elements in that column    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]
    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    precision_table =(cm/cm.sum(axis=0))
    # How did we calculateed precision_table :
    # divide each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]    
    print()
    print("-"*20, "Confusion matrix", "-"*20)
    plot_matrix(cm,labels)

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plot_matrix(precision_table,labels)    
    
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plot_matrix(recall_table,labels)

# %%
# We need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = x_test.shape[0]
cv_data_len = x_cv.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
# We create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.495547988218347
# Log loss on Test Data using Random Model 2.492281181459366
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['x_train', 'x_test', 'x_cv']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = x_train[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = x_train.loc[(y_train['Class']==k) & (x_train[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = x_train[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = x_train['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 222
# BRCA1     136
# TP53       81
# EGFR       68
# PTEN       65
# BRCA2      58
# KIT        47
# BRAF       42
# PDGFRA     31
# PIK3CA     30
# ERBB2      29
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 222 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_train))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_test))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_cv))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (1626, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(x_train['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(x_test['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(x_cv['Gene'])

# %%
train_gene_feature_onehotCoding
# Out:
# <1626x221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1626 stored elements in Compressed Sparse Row format>

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", 
      train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (1626, 221)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1916265890373663
# For values of alpha =  0.0001 The log loss is: 1.1661348221302479
# For values of alpha =  0.001 The log loss is: 1.2187214070257146
# For values of alpha =  0.01 The log loss is: 1.359018865964021
# For values of alpha =  0.1 The log loss is: 1.47181591094075
# For values of alpha =  1 The log loss is: 1.5148150318360536
# For values of best alpha =  0.0001 The train log loss is: 0.9765127884368637
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1661348221302479
# For values of best alpha =  0.0001 The test log loss is: 1.2386044605669404

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", 
      unique_genes.shape[0], " genes in train dataset?")

test_coverage=x_test[x_test['Gene'].isin(list(set(x_train['Gene'])))].shape[0]
cv_coverage=x_cv[x_cv['Gene'].isin(list(set(x_train['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',x_test.shape[0], ":",(test_coverage/x_test.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',x_cv.shape[0],":" ,(cv_coverage/x_cv.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  222  genes in train dataset?
# Ans
# 1. In test data 962 out of 997 : 96.48946840521565
# 2. In cross validation data 680 out of  698 : 97.42120343839542

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = x_train['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1480
# Truncating_Mutations    53
# Amplification           39
# Deletion                28
# Fusions                 15
# Q61H                     3
# M1R                      2
# E17K                     2
# R173C                    2
# EWSR1-ETV1_Fusion        2
# G13V                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,
      "different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1480 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.03259533 0.05658057 0.07380074 ... 0.99876999 0.99938499 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1

# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_train))

# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_test))

# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_cv))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", 
      train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (1626, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(x_train['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(x_test['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(x_cv['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", 
      train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (1626, 1512)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7023251468704603
# For values of alpha =  0.0001 The log loss is: 1.6984125604303977
# For values of alpha =  0.001 The log loss is: 1.698525065473556
# For values of alpha =  0.01 The log loss is: 1.7036428485979798
# For values of alpha =  0.1 The log loss is: 1.7057594769327635
# For values of alpha =  1 The log loss is: 1.7096660796010226
# For values of best alpha =  0.0001 The train log loss is: 0.6447868654292865
# For values of best alpha =  0.0001 The cross validation log loss is: 1.6984125604303977
# For values of best alpha =  0.0001 The test log loss is: 1.726043304300277

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", 
      unique_variations.shape[0], 
      " genes in test and cross validation data sets?")
test_coverage=x_test[x_test['Variation'].isin(list(set(x_train['Variation'])))].shape[0]
cv_coverage=x_cv[x_cv['Variation'].isin(list(set(x_train['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',x_test.shape[0], ":",(test_coverage/x_test.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',x_cv.shape[0],":" ,(cv_coverage/x_cv.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1480  genes in test and cross validation data sets?
# Ans
# 1. In test data 87 out of 997 : 8.72617853560682
# 2. In cross validation data 75 out of  698 : 10.744985673352435

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
x_train['TEXT'].head()
# Out:
# 2719    tumors mutant braf dependent raf mek erk signa...
# 731     assessed somatic alleles six receptor tyrosine...
# 2854    mutation screening breast ovarian cancer predi...
# 589     although colorectal mucinous adenocarcinomas m...
# 1250    present study focused prognostic roles pik3ca ...
# Name: TEXT, dtype: object

# %%
def top_tfidf_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

def top_mean_feats(Xtr, features, min_tfidf=0.1, grp_ids=None, top_n=25):
    ''' Return the top n features that on average are most important amongst documents in rows
        indentified by indices in grp_ids. '''
    if grp_ids:
        D = Xtr[grp_ids].toarray()
    else:
        D = Xtr.toarray()

    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(x_train['TEXT'])

# getting top 1000 feature names (words)
train_text_features = top_mean_feats(train_text_feature_onehotCoding,
                                                text_vectorizer.get_feature_names(),
                                                top_n=1000)['feature'].tolist()

# %%
# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1
train_text_fea_counts
# Out:
# array([6.7270638 , 6.86983127, 0.03870629, ..., 0.03222363, 0.01977127,
#        0.01013553])

# %%
# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = x_train[y_train['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(x_train)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(x_train)
test_text_feature_responseCoding  = get_text_responsecoding(x_test)
cv_text_feature_responseCoding  = get_text_responsecoding(x_cv)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(x_test['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(x_cv['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({0.01578509114429713: 30, 0.046585805258992655: 20, 0.01960899321741639: 8, 0.1939163724717094: 7, 0.24563789848697293: 6, 0.04224448160292929: 6, 0.07313117753319787: 5, 0.025582454938054482: 5, 0.01401980560947496: 5, 0.026437510057015962: 4, 0.022239765302563594: 4, 0.017746965237117773: 4, 0.014907819747765862: 4, 0.04685471382285676: 3, 0.043473470933806144: 3, 0.02795075041818061: 3, 0.02517571256765496: 3, 0.016582759706319887: 3, 0.00781930534647963: 3, 0.004979638353277402: 3, 0.10393469883879206: 2, 0.05121342444750993: 2, 0.04524077086404806: 2, 0.04205941682842487: 2, 0.04014016340540408: 2, 0.03862565271509313: 2, 0.038041331700393505: 2, 0.03296890279033589: 2, 0.030632268321943282: 2, 0.030342658141652074: 2, 0.02454596235664557: 2, 0.024057523210286667: 2, 0.02267135734759679: 2, 0.017170916851166344: 2, 0.0158898226220155: 2, 0.015562424614992807: 2, 0.015173291233653342: 2, 0.012395707164409586: 2, 0.01207758630335634: 2, 0.008314874338520835: 2, 0.006448323099349641: 2, 0.005250336122276609: 2, 25.230661782641715: 1, 14.619154278650697: 1, 13.902912791439856: 1, 12.539658312773179: 1, 11.557118135805286: 1, 9.7756569950678: 1, 6.8698312719276196: 1, 6.727063802123695: 1, 4.882630480535084: 1, 4.183735054460984: 1, 3.9340315601643: 1, 3.7028392565527932: 1, 2.9951604634721143: 1, 2.980745450845843: 1, 2.975872127362985: 1, 2.8688996626177286: 1, 2.772151127030726: 1, 2.760653735499603: 1, 2.7289593462919775: 1, 2.71341402525891: 1, 2.705322956554508: 1, 2.64719625414798: 1, 2.1798453703028917: 1, 2.133080097188803: 1, 2.0399636438921545: 1, 1.98731156614053: 1, 1.9105589390755109: 1, 1.8301887883732406: 1, 1.7708124774664407: 1, 1.7653319396268075: 1, 1.5751230451557736: 1, 1.5689214302204222: 1, 1.5232377521272396: 1, 1.4832334514522463: 1, 1.4700147939239097: 1, 1.4517014289930417: 1, 1.4482418564245463: 1, 1.260590584102792: 1, 1.245594973595666: 1, 1.215948483507791: 1, 1.2108756747748242: 1, 1.1946445565140957: 1, 1.1773336131482643: 1, 1.078673434444453: 1, 1.0767718192003646: 1, 1.039743254605639: 1, 1.0383096917453398: 1, 0.9672005846343532: 1, 0.9607796894331819: 1, 0.9546565470964108: 1, 0.9146413908018399: 1, 0.9074721257954595: 1, 0.8836259555411491: 1, 0.8715021390813604: 1, 0.8443979335287061: 1, 0.7874095842108632: 1, 0.773823681192136: 1, 0.7379242737817759: 1, 0.7258216477706717: 1, 0.7191251389848554: 1, 0.7176244135791755: 1, 0.7119951451038182: 1, 0.7076126772678556: 1, 0.7033240949612126: 1, 0.7008959128891027: 1, 0.6701313236014953: 1, 0.645552420544554: 1, 0.6349499225535814: 1, 0.6303449147387119: 1, 0.6158137045418621: 1, 0.6080592344355551: 1, 0.6045653044769397: 1, 0.6010076116499052: 1, 0.5982491260963325: 1, 0.5912923695565875: 1, 0.5885466583507575: 1, 0.5594816771014409: 1, 0.556784061718807: 1, 0.5561151517104433: 1, 0.5557543155312028: 1, 0.552230939757507: 1, 0.5487878148219449: 1, 0.54252786317294: 1, 0.5411454272865105: 1, 0.5319064003744376: 1, 0.5315974434826053: 1, 0.5261820066833853: 1, 0.5081183615224972: 1, 0.5059159847810173: 1, 0.5045692765760161: 1, 0.5037175547913135: 1, 0.4999363799858398: 1, 0.49268252539721075: 1, 0.4914293004703357: 1, 0.4540187381869635: 1, 0.44893555233364796: 1, 0.43174726646371797: 1, 0.41720127169045956: 1, 0.41345269011776037: 1, 0.41215159894120246: 1, 0.40827917361828864: 1, 0.4062444170213069: 1, 0.4018857997340806: 1, 0.39528933047398185: 1, 0.3878327449434188: 1, 0.3818210266808707: 1, 0.3725711436641271: 1, 0.36712782811862593: 1, 0.3637975865244023: 1, 0.36352633500524023: 1, 0.35619011146047797: 1, 0.3524249800207484: 1, 0.34963484316918864: 1, 0.34585823910603897: 1, 0.3357607629786274: 1, 0.33503156673793155: 1, 0.32694388826285903: 1, 0.3266495822040006: 1, 0.3237223401075762: 1, 0.3166313609021923: 1, 0.31635641345276755: 1, 0.31238887300853196: 1, 0.31071403976084566: 1, 0.3088694072838911: 1, 0.30719769598870694: 1, 0.3028354688509117: 1, 0.30089355527309747: 1, 0.296431968806286: 1, 0.29499065582423034: 1, 0.291988 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3018242453863504
# For values of alpha =  0.0001 The log loss is: 1.1169880723502856
# For values of alpha =  0.001 The log loss is: 1.0879704142976308
# For values of alpha =  0.01 The log loss is: 1.136085313153922
# For values of alpha =  0.1 The log loss is: 1.2939242844465308
# For values of alpha =  1 The log loss is: 1.4841350583039146
# For values of best alpha =  0.001 The train log loss is: 0.562870194492767
# For values of best alpha =  0.001 The cross validation log loss is: 1.0879704142976308
# For values of best alpha =  0.001 The test log loss is: 1.1887664944272573

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])   
    
    df_text_features = top_mean_feats(df_text_fea,
                                      df_text_vec.get_feature_names(),
                                      top_n=1000)['feature'].tolist()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(x_test)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(x_cv)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 64.0 % of word of test data appeared in train data
# 61.3 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models

def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer()
    var_count_vec = TfidfVectorizer()
    text_count_vec = TfidfVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(x_train['Gene'])
    var_vec  = var_count_vec.fit(x_train['Variation'])
    text_vec = text_count_vec.fit(x_train['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:            
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <br/>
# <p style="font-size:24px;text-align:left"> <b>Stacking the three types of features </b><p>
# <br/>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(y_train['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(y_test['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(y_cv['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (1626, 49454)
# (number of data points * number of features) in test data =  (997, 49454)
# (number of data points * number of features) in cross validation data = (698, 49454)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (1626, 27)
# (number of data points * number of features) in test data =  (997, 27)
# (number of data points * number of features) in cross validation data = (698, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2434817958377895
# for alpha = 0.0001
# Log Loss : 1.2411543649784131
# for alpha = 0.001
# Log Loss : 1.2467932317481656
# for alpha = 0.1
# Log Loss : 1.2513717552915025
# for alpha = 1
# Log Loss : 1.2808245631638173
# for alpha = 10
# Log Loss : 1.3243036031065867
# for alpha = 100
# Log Loss : 1.2457266905629747
# for alpha = 1000
# Log Loss : 1.1916144900984174
# For values of best alpha =  1000 The train log loss is: 0.9232246788426147
# For values of best alpha =  1000 The cross validation log loss is: 1.1916144900984174
# For values of best alpha =  1000 The test log loss is: 1.2700152021736377

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.1916144900984174
# Number of missclassified point : 0.4169054441260745
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0483 0.0451 0.0119 0.0762 0.0279 0.0235 0.743  0.0113 0.0128]]
# Actual Class : 9
# --------------------------------------------------
# 14 Text feature [cells] present in test data point [True]
# 17 Text feature [kinase] present in test data point [True]
# 19 Text feature [expressing] present in test data point [True]
# 20 Text feature [cell] present in test data point [True]
# 21 Text feature [inhibitor] present in test data point [True]
# 22 Text feature [activation] present in test data point [True]
# 23 Text feature [activated] present in test data point [True]
# 24 Text feature [contrast] present in test data point [True]
# 25 Text feature [factor] present in test data point [True]
# 26 Text feature [presence] present in test data point [True]
# 27 Text feature [growth] present in test data point [True]
# 28 Text feature [addition] present in test data point [True]
# 29 Text feature [shown] present in test data point [True]
# 30 Text feature [also] present in test data point [True]
# 32 Text feature [signaling] present in test data point [True]
# 33 Text feature [10] present in test data point [True]
# 34 Text feature [phosphorylation] present in test data point [True]
# 36 Text feature [independent] present in test data point [True]
# 37 Text feature [however] present in test data point [True]
# 38 Text feature [found] present in test data point [True]
# 39 Text feature [similar] present in test data point [True]
# 41 Text feature [compared] present in test data point [True]
# 42 Text feature [previously] present in test data point [True]
# 43 Text feature [treated] present in test data point [True]
# 44 Text feature [3b] present in test data point [True]
# 45 Text feature [1a] present in test data point [True]
# 46 Text feature [consistent] present in test data point [True]
# 47 Text feature [treatment] present in test data point [True]
# 49 Text feature [mutations] present in test data point [True]
# 52 Text feature [constitutive] present in test data point [True]
# 53 Text feature [tyrosine] present in test data point [True]
# 54 Text feature [using] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 56 Text feature [potential] present in test data point [True]
# 57 Text feature [activating] present in test data point [True]
# 58 Text feature [inhibitors] present in test data point [True]
# 59 Text feature [sensitive] present in test data point [True]
# 61 Text feature [increased] present in test data point [True]
# 62 Text feature [mutant] present in test data point [True]
# 63 Text feature [small] present in test data point [True]
# 64 Text feature [reported] present in test data point [True]
# 65 Text feature [figure] present in test data point [True]
# 67 Text feature [furthermore] present in test data point [True]
# 68 Text feature [total] present in test data point [True]
# 69 Text feature [constitutively] present in test data point [True]
# 70 Text feature [followed] present in test data point [True]
# 71 Text feature [3a] present in test data point [True]
# 72 Text feature [observed] present in test data point [True]
# 73 Text feature [may] present in test data point [True]
# 74 Text feature [concentrations] present in test data point [True]
# 79 Text feature [interestingly] present in test data point [True]
# 81 Text feature [obtained] present in test data point [True]
# 82 Text feature [without] present in test data point [True]
# 83 Text feature [approximately] present in test data point [True]
# 84 Text feature [confirmed] present in test data point [True]
# 85 Text feature [proliferation] present in test data point [True]
# 86 Text feature [mutation] present in test data point [True]
# 87 Text feature [serum] present in test data point [True]
# 88 Text feature [showed] present in test data point [True]
# 89 Text feature [antibodies] present in test data point [True]
# 91 Text feature [suggests] present in test data point [True]
# 92 Text feature [absence] present in test data point [True]
# 93 Text feature [two] present in test data point [True]
# 94 Text feature [studies] present in test data point [True]
# 95 Text feature [hours] present in test data point [True]
# 96 Text feature [oncogenic] present in test data point [True]
# 99 Text feature [expressed] present in test data point [True]
# 100 Text feature [12] present in test data point [True]
# 103 Text feature [domain] present in test data point [True]
# 104 Text feature [receptor] present in test data point [True]
# 105 Text feature [inhibited] present in test data point [True]
# 106 Text feature [activate] present in test data point [True]
# 107 Text feature [identified] present in test data point [True]
# 108 Text feature [measured] present in test data point [True]
# 109 Text feature [induced] present in test data point [True]
# 110 Text feature [results] present in test data point [True]
# 111 Text feature [tumor] present in test data point [True]
# 112 Text feature [whether] present in test data point [True]
# 113 Text feature [expression] present in test data point [True]
# 115 Text feature [1b] present in test data point [True]
# 116 Text feature [culture] present in test data point [True]
# 117 Text feature [4b] present in test data point [True]
# 118 Text feature [survival] present in test data point [True]
# 119 Text feature [study] present in test data point [True]
# 120 Text feature [tissue] present in test data point [True]
# 121 Text feature [positive] present in test data point [True]
# 122 Text feature [anti] present in test data point [True]
# 123 Text feature [discussion] present in test data point [True]
# 126 Text feature [4a] present in test data point [True]
# 127 Text feature [suggesting] present in test data point [True]
# 129 Text feature [common] present in test data point [True]
# 130 Text feature [previous] present in test data point [True]
# 131 Text feature [assessed] present in test data point [True]
# 133 Text feature [specific] present in test data point [True]
# 138 Text feature [antibody] present in test data point [True]
# 139 Text feature [active] present in test data point [True]
# 140 Text feature [examined] present in test data point [True]
# 141 Text feature [western] present in test data point [True]
# 144 Text feature [express] present in test data point [True]
# 145 Text feature [following] present in test data point [True]
# 148 Text feature [role] present in test data point [True]
# 150 Text feature [13] present in test data point [True]
# 151 Text feature [lead] present in test data point [True]
# 152 Text feature [could] present in test data point [True]
# 153 Text feature [trials] present in test data point [True]
# 154 Text feature [go] present in test data point [True]
# 159 Text feature [effective] present in test data point [True]
# 163 Text feature [findings] present in test data point [True]
# 164 Text feature [single] present in test data point [True]
# 165 Text feature [next] present in test data point [True]
# 166 Text feature [3c] present in test data point [True]
# 168 Text feature [clinical] present in test data point [True]
# 169 Text feature [targeted] present in test data point [True]
# 170 Text feature [three] present in test data point [True]
# 171 Text feature [18] present in test data point [True]
# 174 Text feature [additional] present in test data point [True]
# 175 Text feature [different] present in test data point [True]
# 176 Text feature [lysed] present in test data point [True]
# 177 Text feature [others] present in test data point [True]
# 180 Text feature [several] present in test data point [True]
# 181 Text feature [development] present in test data point [True]
# 182 Text feature [lines] present in test data point [True]
# 183 Text feature [conditions] present in test data point [True]
# 184 Text feature [analysis] present in test data point [True]
# 185 Text feature [show] present in test data point [True]
# 189 Text feature [sequencing] present in test data point [True]
# 190 Text feature [effects] present in test data point [True]
# 191 Text feature [another] present in test data point [True]
# 192 Text feature [cancers] present in test data point [True]
# 193 Text feature [due] present in test data point [True]
# 196 Text feature [one] present in test data point [True]
# 197 Text feature [test] present in test data point [True]
# 203 Text feature [2c] present in test data point [True]
# 207 Text feature [pathway] present in test data point [True]
# 208 Text feature [drug] present in test data point [True]
# 210 Text feature [result] present in test data point [True]
# 213 Text feature [represents] present in test data point [True]
# 214 Text feature [might] present in test data point [True]
# 215 Text feature [seeded] present in test data point [True]
# 216 Text feature [target] present in test data point [True]
# 217 Text feature [supplemented] present in test data point [True]
# 220 Text feature [somatic] present in test data point [True]
# 221 Text feature [vitro] present in test data point [True]
# 222 Text feature [2b] present in test data point [True]
# 224 Text feature [tumors] present in test data point [True]
# 226 Text feature [despite] present in test data point [True]
# 227 Text feature [incubated] present in test data point [True]
# 229 Text feature [less] present in test data point [True]
# 230 Text feature [lung] present in test data point [True]
# 232 Text feature [collection] present in test data point [True]
# 234 Text feature [promote] present in test data point [True]
# 236 Text feature [maintained] present in test data point [True]
# 237 Text feature [first] present in test data point [True]
# 241 Text feature [manufacturer] present in test data point [True]
# 242 Text feature [santa] present in test data point [True]
# 246 Text feature [lysates] present in test data point [True]
# 247 Text feature [determined] present in test data point [True]
# 248 Text feature [collected] present in test data point [True]
# 249 Text feature [generated] present in test data point [True]
# 250 Text feature [sigma] present in test data point [True]
# 255 Text feature [cancer] present in test data point [True]
# 258 Text feature [analyzed] present in test data point [True]
# 259 Text feature [agent] present in test data point [True]
# 260 Text feature [human] present in test data point [True]
# 261 Text feature [overexpression] present in test data point [True]
# 262 Text feature [protocol] present in test data point [True]
# 263 Text feature [according] present in test data point [True]
# 265 Text feature [non] present in test data point [True]
# 266 Text feature [significantly] present in test data point [True]
# 267 Text feature [selected] present in test data point [True]
# 268 Text feature [four] present in test data point [True]
# 269 Text feature [dependent] present in test data point [True]
# 270 Text feature [plates] present in test data point [True]
# 272 Text feature [represent] present in test data point [True]
# 273 Text feature [part] present in test data point [True]
# 274 Text feature [murine] present in test data point [True]
# 276 Text feature [mediated] present in test data point [True]
# 277 Text feature [currently] present in test data point [True]
# 278 Text feature [stimulation] present in test data point [True]
# 281 Text feature [samples] present in test data point [True]
# 283 Text feature [wt] present in test data point [True]
# 286 Text feature [resulted] present in test data point [True]
# 287 Text feature [blot] present in test data point [True]
# 288 Text feature [time] present in test data point [True]
# 289 Text feature [derived] present in test data point [True]
# 290 Text feature [free] present in test data point [True]
# 291 Text feature [mutants] present in test data point [True]
# 292 Text feature [possibility] present in test data point [True]
# 295 Text feature [1c] present in test data point [True]
# 296 Text feature [experiments] present in test data point [True]
# 297 Text feature [harbor] present in test data point [True]
# 299 Text feature [3e] present in test data point [True]
# 300 Text feature [40] present in test data point [True]
# 302 Text feature [variety] present in test data point [True]
# 304 Text feature [directly] present in test data point [True]
# 305 Text feature [initial] present in test data point [True]
# 306 Text feature [provided] present in test data point [True]
# 308 Text feature [transduction] present in test data point [True]
# 310 Text feature [software] present in test data point [True]
# 314 Text feature [regulated] present in test data point [True]
# 318 Text feature [medium] present in test data point [True]
# 319 Text feature [50] present in test data point [True]
# 321 Text feature [directed] present in test data point [True]
# 326 Text feature [indicated] present in test data point [True]
# 330 Text feature [100] present in test data point [True]
# 331 Text feature [containing] present in test data point [True]
# 340 Text feature [levels] present in test data point [True]
# 342 Text feature [sample] present in test data point [True]
# 343 Text feature [30] present in test data point [True]
# 345 Text feature [ml] present in test data point [True]
# 346 Text feature [vector] present in test data point [True]
# 348 Text feature [activity] present in test data point [True]
# 350 Text feature [concentration] present in test data point [True]
# 352 Text feature [open] present in test data point [True]
# 355 Text feature [even] present in test data point [True]
# 356 Text feature [4c] present in test data point [True]
# 357 Text feature [important] present in test data point [True]
# 359 Text feature [cellular] present in test data point [True]
# 361 Text feature [introduction] present in test data point [True]
# 366 Text feature [agents] present in test data point [True]
# 371 Text feature [carcinoma] present in test data point [True]
# 372 Text feature [would] present in test data point [True]
# 374 Text feature [150] present in test data point [True]
# 375 Text feature [stable] present in test data point [True]
# 377 Text feature [completely] present in test data point [True]
# 378 Text feature [used] present in test data point [True]
# 380 Text feature [importance] present in test data point [True]
# 382 Text feature [line] present in test data point [True]
# 384 Text feature [regulation] present in test data point [True]
# 385 Text feature [complete] present in test data point [True]
# 386 Text feature [demonstrate] present in test data point [True]
# 387 Text feature [primary] present in test data point [True]
# 389 Text feature [data] present in test data point [True]
# 391 Text feature [2a] present in test data point [True]
# 394 Text feature [16] present in test data point [True]
# 401 Text feature [serine] present in test data point [True]
# 404 Text feature [doses] present in test data point [True]
# 410 Text feature [therefore] present in test data point [True]
# 413 Text feature [plays] present in test data point [True]
# 422 Text feature [atcc] present in test data point [True]
# 424 Text feature [epithelial] present in test data point [True]
# 425 Text feature [manner] present in test data point [True]
# 426 Text feature [green] present in test data point [True]
# 427 Text feature [occurred] present in test data point [True]
# 428 Text feature [greater] present in test data point [True]
# 430 Text feature [stably] present in test data point [True]
# 434 Text feature [control] present in test data point [True]
# 436 Text feature [fbs] present in test data point [True]
# 437 Text feature [conformation] present in test data point [True]
# 439 Text feature [remains] present in test data point [True]
# 441 Text feature [grown] present in test data point [True]
# 444 Text feature [example] present in test data point [True]
# 447 Text feature [transformed] present in test data point [True]
# 450 Text feature [form] present in test data point [True]
# 451 Text feature [identify] present in test data point [True]
# 454 Text feature [sensitivity] present in test data point [True]
# 457 Text feature [epidermal] present in test data point [True]
# 465 Text feature [coding] present in test data point [True]
# 467 Text feature [failed] present in test data point [True]
# 468 Text feature [dmem] present in test data point [True]
# 470 Text feature [observations] present in test data point [True]
# 471 Text feature [11] present in test data point [True]
# 472 Text feature [fixed] present in test data point [True]
# 473 Text feature [endogenous] present in test data point [True]
# 474 Text feature [associated] present in test data point [True]
# 481 Text feature [stained] present in test data point [True]
# 483 Text feature [harboring] present in test data point [True]
# 486 Text feature [type] present in test data point [True]
# 487 Text feature [comparable] present in test data point [True]
# 488 Text feature [five] present in test data point [True]
# 489 Text feature [provide] present in test data point [True]
# 492 Text feature [4d] present in test data point [True]
# 494 Text feature [whole] present in test data point [True]
# 498 Text feature [virus] present in test data point [True]
# 500 Text feature [able] present in test data point [True]
# 501 Text feature [plated] present in test data point [True]
# 502 Text feature [generate] present in test data point [True]
# 507 Text feature [response] present in test data point [True]
# 509 Text feature [requires] present in test data point [True]
# 512 Text feature [resistant] present in test data point [True]
# 516 Text feature [bovine] present in test data point [True]
# 523 Text feature [carried] present in test data point [True]
# 526 Text feature [ca] present in test data point [True]
# 527 Text feature [university] present in test data point [True]
# 529 Text feature [number] present in test data point [True]
# 532 Text feature [effect] present in test data point [True]
# 534 Text feature [work] present in test data point [True]
# 535 Text feature [mouse] present in test data point [True]
# 536 Text feature [washed] present in test data point [True]
# 539 Text feature [80] present in test data point [True]
# 540 Text feature [factors] present in test data point [True]
# 543 Text feature [required] present in test data point [True]
# 544 Text feature [many] present in test data point [True]
# 547 Text feature [sites] present in test data point [True]
# 548 Text feature [statistical] present in test data point [True]
# 549 Text feature [amplification] present in test data point [True]
# 563 Text feature [blocked] present in test data point [True]
# 570 Text feature [reagent] present in test data point [True]
# 574 Text feature [nsclc] present in test data point [True]
# 576 Text feature [technologies] present in test data point [True]
# 577 Text feature [current] present in test data point [True]
# 580 Text feature [primers] present in test data point [True]
# 581 Text feature [wild] present in test data point [True]
# 583 Text feature [signal] present in test data point [True]
# 585 Text feature [event] present in test data point [True]
# 590 Text feature [egfr] present in test data point [True]
# 602 Text feature [least] present in test data point [True]
# 603 Text feature [clone] present in test data point [True]
# 619 Text feature [purchased] present in test data point [True]
# 629 Text feature [critical] present in test data point [True]
# 630 Text feature [independently] present in test data point [True]
# 632 Text feature [reaction] present in test data point [True]
# 633 Text feature [erk] present in test data point [True]
# 635 Text feature [500] present in test data point [True]
# 638 Text feature [transfection] present in test data point [True]
# 640 Text feature [constructs] present in test data point [True]
# 641 Text feature [sufficient] present in test data point [True]
# 647 Text feature [threonine] present in test data point [True]
# 648 Text feature [biosciences] present in test data point [True]
# 649 Text feature [rpmi] present in test data point [True]
# 653 Text feature [exogenous] present in test data point [True]
# 655 Text feature [pbs] present in test data point [True]
# 656 Text feature [known] present in test data point [True]
# 657 Text feature [viral] present in test data point [True]
# 663 Text feature [note] present in test data point [True]
# 664 Text feature [top] present in test data point [True]
# 670 Text feature [200] present in test data point [True]
# 674 Text feature [targeting] present in test data point [True]
# 684 Text feature [cdna] present in test data point [True]
# 685 Text feature [buffer] present in test data point [True]
# 690 Text feature [near] present in test data point [True]
# 692 Text feature [since] present in test data point [True]
# 693 Text feature [sections] present in test data point [True]
# 695 Text feature [protein] present in test data point [True]
# 696 Text feature [amplified] present in test data point [True]
# 698 Text feature [acid] present in test data point [True]
# 699 Text feature [sanger] present in test data point [True]
# 701 Text feature [certain] present in test data point [True]
# 704 Text feature [viability] present in test data point [True]
# 713 Text feature [ongoing] present in test data point [True]
# 714 Text feature [membrane] present in test data point [True]
# 715 Text feature [lysis] present in test data point [True]
# 717 Text feature [strategies] present in test data point [True]
# 719 Text feature [occurs] present in test data point [True]
# 723 Text feature [advantage] present in test data point [True]
# 724 Text feature [tested] present in test data point [True]
# 730 Text feature [products] present in test data point [True]
# 734 Text feature [implications] present in test data point [True]
# 738 Text feature [instructions] present in test data point [True]
# 740 Text feature [modest] present in test data point [True]
# 745 Text feature [reduced] present in test data point [True]
# 746 Text feature [times] present in test data point [True]
# 747 Text feature [types] present in test data point [True]
# 748 Text feature [louis] present in test data point [True]
# 757 Text feature [counted] present in test data point [True]
# 759 Text feature [triplicate] present in test data point [True]
# 760 Text feature [genes] present in test data point [True]
# 763 Text feature [media] present in test data point [True]
# 765 Text feature [block] present in test data point [True]
# 766 Text feature [proteins] present in test data point [True]
# 767 Text feature [respective] present in test data point [True]
# 771 Text feature [regulates] present in test data point [True]
# 772 Text feature [rapidly] present in test data point [True]
# 775 Text feature [gain] present in test data point [True]
# 778 Text feature [bank] present in test data point [True]
# 779 Text feature [retroviral] present in test data point [True]
# 780 Text feature [life] present in test data point [True]
# 784 Text feature [methods] present in test data point [True]
# 788 Text feature [diego] present in test data point [True]
# 789 Text feature [serve] present in test data point [True]
# 793 Text feature [pattern] present in test data point [True]
# 797 Text feature [included] present in test data point [True]
# 799 Text feature [briefly] present in test data point [True]
# 802 Text feature [immunoblot] present in test data point [True]
# 803 Text feature [case] present in test data point [True]
# 806 Text feature [inactive] present in test data point [True]
# 810 Text feature [detection] present in test data point [True]
# 813 Text feature [transduced] present in test data point [True]
# 817 Text feature [fluorescent] present in test data point [True]
# 818 Text feature [1e] present in test data point [True]
# 823 Text feature [et] present in test data point [True]
# 825 Text feature [supports] present in test data point [True]
# 829 Text feature [processes] present in test data point [True]
# 833 Text feature [acquired] present in test data point [True]
# 835 Text feature [clones] present in test data point [True]
# 839 Text feature [fetal] present in test data point [True]
# 841 Text feature [site] present in test data point [True]
# 842 Text feature [al] present in test data point [True]
# 843 Text feature [involved] present in test data point [True]
# 846 Text feature [3f] present in test data point [True]
# 847 Text feature [solution] present in test data point [True]
# 850 Text feature [induce] present in test data point [True]
# 856 Text feature [phosphorylated] present in test data point [True]
# 858 Text feature [reports] present in test data point [True]
# 860 Text feature [groups] present in test data point [True]
# 862 Text feature [mixed] present in test data point [True]
# 863 Text feature [engineered] present in test data point [True]
# 866 Text feature [4e] present in test data point [True]
# 868 Text feature [60] present in test data point [True]
# 869 Text feature [blocking] present in test data point [True]
# 873 Text feature [4f] present in test data point [True]
# 876 Text feature [overnight] present in test data point [True]
# 877 Text feature [gift] present in test data point [True]
# 881 Text feature [roles] present in test data point [True]
# 882 Text feature [05] present in test data point [True]
# 886 Text feature [equivalent] present in test data point [True]
# 888 Text feature [amino] present in test data point [True]
# 890 Text feature [listed] present in test data point [True]
# 896 Text feature [36] present in test data point [True]
# 901 Text feature [marker] present in test data point [True]
# 904 Text feature [adding] present in test data point [True]
# 906 Text feature [quikchange] present in test data point [True]
# 909 Text feature [inhibit] present in test data point [True]
# 912 Text feature [given] present in test data point [True]
# 919 Text feature [kindly] present in test data point [True]
# 920 Text feature [homology] present in test data point [True]
# 927 Text feature [insensitive] present in test data point [True]
# 928 Text feature [akt] present in test data point [True]
# 931 Text feature [resuspended] present in test data point [True]
# 933 Text feature [promotes] present in test data point [True]
# 938 Text feature [5a] present in test data point [True]
# 939 Text feature [second] present in test data point [True]
# 946 Text feature [components] present in test data point [True]
# 948 Text feature [image] present in test data point [True]
# 949 Text feature [develop] present in test data point [True]
# 950 Text feature [drugs] present in test data point [True]
# 957 Text feature [promoted] present in test data point [True]
# 964 Text feature [origin] present in test data point [True]
# 970 Text feature [markedly] present in test data point [True]
# 975 Text feature [alterations] present in test data point [True]
# 981 Text feature [harvested] present in test data point [True]
# 984 Text feature [resistance] present in test data point [True]
# 989 Text feature [equal] present in test data point [True]
# 993 Text feature [partial] present in test data point [True]
# 994 Text feature [genetic] present in test data point [True]
# 995 Text feature [mg] present in test data point [True]
# 997 Text feature [view] present in test data point [True]
# Out of the top  1000  features  437 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 55
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0448 0.0652 0.0101 0.0493 0.0296 0.0225 0.7713 0.0051 0.0021]]
# Actual Class : 7
# --------------------------------------------------
# 14 Text feature [cells] present in test data point [True]
# 17 Text feature [kinase] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 19 Text feature [expressing] present in test data point [True]
# 20 Text feature [cell] present in test data point [True]
# 21 Text feature [inhibitor] present in test data point [True]
# 22 Text feature [activation] present in test data point [True]
# 23 Text feature [activated] present in test data point [True]
# 24 Text feature [contrast] present in test data point [True]
# 25 Text feature [factor] present in test data point [True]
# 26 Text feature [presence] present in test data point [True]
# 27 Text feature [growth] present in test data point [True]
# 28 Text feature [addition] present in test data point [True]
# 29 Text feature [shown] present in test data point [True]
# 30 Text feature [also] present in test data point [True]
# 31 Text feature [suggest] present in test data point [True]
# 32 Text feature [signaling] present in test data point [True]
# 33 Text feature [10] present in test data point [True]
# 34 Text feature [phosphorylation] present in test data point [True]
# 35 Text feature [well] present in test data point [True]
# 36 Text feature [independent] present in test data point [True]
# 37 Text feature [however] present in test data point [True]
# 38 Text feature [found] present in test data point [True]
# 39 Text feature [similar] present in test data point [True]
# 40 Text feature [recently] present in test data point [True]
# 41 Text feature [compared] present in test data point [True]
# 42 Text feature [previously] present in test data point [True]
# 43 Text feature [treated] present in test data point [True]
# 44 Text feature [3b] present in test data point [True]
# 45 Text feature [1a] present in test data point [True]
# 46 Text feature [consistent] present in test data point [True]
# 47 Text feature [treatment] present in test data point [True]
# 48 Text feature [mechanism] present in test data point [True]
# 49 Text feature [mutations] present in test data point [True]
# 50 Text feature [described] present in test data point [True]
# 51 Text feature [enhanced] present in test data point [True]
# 52 Text feature [constitutive] present in test data point [True]
# 53 Text feature [tyrosine] present in test data point [True]
# 54 Text feature [using] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 56 Text feature [potential] present in test data point [True]
# 57 Text feature [activating] present in test data point [True]
# 58 Text feature [inhibitors] present in test data point [True]
# 59 Text feature [sensitive] present in test data point [True]
# 60 Text feature [demonstrated] present in test data point [True]
# 61 Text feature [increased] present in test data point [True]
# 62 Text feature [mutant] present in test data point [True]
# 63 Text feature [small] present in test data point [True]
# 64 Text feature [reported] present in test data point [True]
# 65 Text feature [figure] present in test data point [True]
# 66 Text feature [fig] present in test data point [True]
# 67 Text feature [furthermore] present in test data point [True]
# 68 Text feature [total] present in test data point [True]
# 69 Text feature [constitutively] present in test data point [True]
# 70 Text feature [followed] present in test data point [True]
# 71 Text feature [3a] present in test data point [True]
# 72 Text feature [observed] present in test data point [True]
# 73 Text feature [may] present in test data point [True]
# 74 Text feature [concentrations] present in test data point [True]
# 75 Text feature [higher] present in test data point [True]
# 76 Text feature [respectively] present in test data point [True]
# 77 Text feature [increase] present in test data point [True]
# 78 Text feature [various] present in test data point [True]
# 79 Text feature [interestingly] present in test data point [True]
# 80 Text feature [including] present in test data point [True]
# 81 Text feature [obtained] present in test data point [True]
# 83 Text feature [approximately] present in test data point [True]
# 84 Text feature [confirmed] present in test data point [True]
# 85 Text feature [proliferation] present in test data point [True]
# 86 Text feature [mutation] present in test data point [True]
# 87 Text feature [serum] present in test data point [True]
# 88 Text feature [showed] present in test data point [True]
# 89 Text feature [antibodies] present in test data point [True]
# 91 Text feature [suggests] present in test data point [True]
# 92 Text feature [absence] present in test data point [True]
# 93 Text feature [two] present in test data point [True]
# 94 Text feature [studies] present in test data point [True]
# 95 Text feature [hours] present in test data point [True]
# 96 Text feature [oncogenic] present in test data point [True]
# 97 Text feature [performed] present in test data point [True]
# 99 Text feature [expressed] present in test data point [True]
# 100 Text feature [12] present in test data point [True]
# 101 Text feature [molecular] present in test data point [True]
# 102 Text feature [pathways] present in test data point [True]
# 103 Text feature [domain] present in test data point [True]
# 104 Text feature [receptor] present in test data point [True]
# 105 Text feature [inhibited] present in test data point [True]
# 106 Text feature [activate] present in test data point [True]
# 107 Text feature [identified] present in test data point [True]
# 108 Text feature [measured] present in test data point [True]
# 109 Text feature [induced] present in test data point [True]
# 110 Text feature [results] present in test data point [True]
# 111 Text feature [tumor] present in test data point [True]
# 112 Text feature [whether] present in test data point [True]
# 113 Text feature [expression] present in test data point [True]
# 114 Text feature [15] present in test data point [True]
# 115 Text feature [1b] present in test data point [True]
# 116 Text feature [culture] present in test data point [True]
# 118 Text feature [survival] present in test data point [True]
# 119 Text feature [study] present in test data point [True]
# 120 Text feature [tissue] present in test data point [True]
# 121 Text feature [positive] present in test data point [True]
# 122 Text feature [anti] present in test data point [True]
# 123 Text feature [discussion] present in test data point [True]
# 124 Text feature [commonly] present in test data point [True]
# 125 Text feature [together] present in test data point [True]
# 126 Text feature [4a] present in test data point [True]
# 127 Text feature [suggesting] present in test data point [True]
# 128 Text feature [per] present in test data point [True]
# 129 Text feature [common] present in test data point [True]
# 130 Text feature [previous] present in test data point [True]
# 131 Text feature [assessed] present in test data point [True]
# 132 Text feature [recent] present in test data point [True]
# 133 Text feature [specific] present in test data point [True]
# 134 Text feature [either] present in test data point [True]
# 135 Text feature [high] present in test data point [True]
# 136 Text feature [report] present in test data point [True]
# 137 Text feature [led] present in test data point [True]
# 138 Text feature [antibody] present in test data point [True]
# 139 Text feature [active] present in test data point [True]
# 140 Text feature [examined] present in test data point [True]
# 141 Text feature [western] present in test data point [True]
# 142 Text feature [occur] present in test data point [True]
# 143 Text feature [cultured] present in test data point [True]
# 144 Text feature [express] present in test data point [True]
# 145 Text feature [following] present in test data point [True]
# 146 Text feature [although] present in test data point [True]
# 147 Text feature [kinases] present in test data point [True]
# 148 Text feature [role] present in test data point [True]
# 149 Text feature [therapeutic] present in test data point [True]
# 150 Text feature [13] present in test data point [True]
# 151 Text feature [lead] present in test data point [True]
# 152 Text feature [could] present in test data point [True]
# 153 Text feature [trials] present in test data point [True]
# 154 Text feature [go] present in test data point [True]
# 155 Text feature [determine] present in test data point [True]
# 156 Text feature [present] present in test data point [True]
# 157 Text feature [suggested] present in test data point [True]
# 158 Text feature [institutional] present in test data point [True]
# 159 Text feature [effective] present in test data point [True]
# 160 Text feature [detected] present in test data point [True]
# 161 Text feature [leading] present in test data point [True]
# 162 Text feature [thus] present in test data point [True]
# 163 Text feature [findings] present in test data point [True]
# 164 Text feature [single] present in test data point [True]
# 165 Text feature [next] present in test data point [True]
# 166 Text feature [3c] present in test data point [True]
# 167 Text feature [revealed] present in test data point [True]
# 168 Text feature [clinical] present in test data point [True]
# 169 Text feature [targeted] present in test data point [True]
# 170 Text feature [three] present in test data point [True]
# 171 Text feature [18] present in test data point [True]
# 172 Text feature [phospho] present in test data point [True]
# 173 Text feature [resulting] present in test data point [True]
# 174 Text feature [additional] present in test data point [True]
# 175 Text feature [different] present in test data point [True]
# 177 Text feature [others] present in test data point [True]
# 178 Text feature [20] present in test data point [True]
# 179 Text feature [similarly] present in test data point [True]
# 180 Text feature [several] present in test data point [True]
# 181 Text feature [development] present in test data point [True]
# 182 Text feature [lines] present in test data point [True]
# 183 Text feature [conditions] present in test data point [True]
# 184 Text feature [analysis] present in test data point [True]
# 185 Text feature [show] present in test data point [True]
# 186 Text feature [patients] present in test data point [True]
# 187 Text feature [whereas] present in test data point [True]
# 188 Text feature [sequenced] present in test data point [True]
# 189 Text feature [sequencing] present in test data point [True]
# 190 Text feature [effects] present in test data point [True]
# 191 Text feature [another] present in test data point [True]
# 192 Text feature [cancers] present in test data point [True]
# 193 Text feature [due] present in test data point [True]
# 194 Text feature [technology] present in test data point [True]
# 195 Text feature [contribute] present in test data point [True]
# 196 Text feature [one] present in test data point [True]
# 197 Text feature [test] present in test data point [True]
# 198 Text feature [transformation] present in test data point [True]
# 199 Text feature [point] present in test data point [True]
# 200 Text feature [indicate] present in test data point [True]
# 201 Text feature [biotechnology] present in test data point [True]
# 202 Text feature [new] present in test data point [True]
# 203 Text feature [2c] present in test data point [True]
# 207 Text feature [pathway] present in test data point [True]
# 208 Text feature [drug] present in test data point [True]
# 209 Text feature [keywords] present in test data point [True]
# 210 Text feature [result] present in test data point [True]
# 211 Text feature [25] present in test data point [True]
# 214 Text feature [might] present in test data point [True]
# 216 Text feature [target] present in test data point [True]
# 218 Text feature [table] present in test data point [True]
# 219 Text feature [within] present in test data point [True]
# 220 Text feature [somatic] present in test data point [True]
# 221 Text feature [vitro] present in test data point [True]
# 222 Text feature [2b] present in test data point [True]
# 223 Text feature [representative] present in test data point [True]
# 224 Text feature [tumors] present in test data point [True]
# 226 Text feature [despite] present in test data point [True]
# 227 Text feature [incubated] present in test data point [True]
# 228 Text feature [relative] present in test data point [True]
# 229 Text feature [less] present in test data point [True]
# 230 Text feature [lung] present in test data point [True]
# 231 Text feature [genomic] present in test data point [True]
# 232 Text feature [collection] present in test data point [True]
# 233 Text feature [unlike] present in test data point [True]
# 234 Text feature [promote] present in test data point [True]
# 235 Text feature [lower] present in test data point [True]
# 236 Text feature [maintained] present in test data point [True]
# 237 Text feature [first] present in test data point [True]
# 238 Text feature [gene] present in test data point [True]
# 239 Text feature [mechanisms] present in test data point [True]
# 240 Text feature [24] present in test data point [True]
# 241 Text feature [manufacturer] present in test data point [True]
# 242 Text feature [santa] present in test data point [True]
# 244 Text feature [confirm] present in test data point [True]
# 245 Text feature [96] present in test data point [True]
# 246 Text feature [lysates] present in test data point [True]
# 247 Text feature [determined] present in test data point [True]
# 249 Text feature [generated] present in test data point [True]
# 250 Text feature [sigma] present in test data point [True]
# 251 Text feature [cruz] present in test data point [True]
# 252 Text feature [27] present in test data point [True]
# 253 Text feature [taken] present in test data point [True]
# 254 Text feature [identification] present in test data point [True]
# 255 Text feature [cancer] present in test data point [True]
# 256 Text feature [therapies] present in test data point [True]
# 258 Text feature [analyzed] present in test data point [True]
# 259 Text feature [agent] present in test data point [True]
# 260 Text feature [human] present in test data point [True]
# 261 Text feature [overexpression] present in test data point [True]
# 264 Text feature [indicating] present in test data point [True]
# 265 Text feature [non] present in test data point [True]
# 266 Text feature [significantly] present in test data point [True]
# 267 Text feature [selected] present in test data point [True]
# 269 Text feature [dependent] present in test data point [True]
# 270 Text feature [plates] present in test data point [True]
# 271 Text feature [19] present in test data point [True]
# 273 Text feature [part] present in test data point [True]
# 274 Text feature [murine] present in test data point [True]
# 276 Text feature [mediated] present in test data point [True]
# 277 Text feature [currently] present in test data point [True]
# 278 Text feature [stimulation] present in test data point [True]
# 279 Text feature [mitogen] present in test data point [True]
# 280 Text feature [confer] present in test data point [True]
# 281 Text feature [samples] present in test data point [True]
# 282 Text feature [seen] present in test data point [True]
# 283 Text feature [wt] present in test data point [True]
# 284 Text feature [days] present in test data point [True]
# 285 Text feature [elevated] present in test data point [True]
# 286 Text feature [resulted] present in test data point [True]
# 288 Text feature [time] present in test data point [True]
# 289 Text feature [derived] present in test data point [True]
# 291 Text feature [mutants] present in test data point [True]
# 292 Text feature [possibility] present in test data point [True]
# 293 Text feature [48] present in test data point [True]
# 294 Text feature [ligand] present in test data point [True]
# 295 Text feature [1c] present in test data point [True]
# 296 Text feature [experiments] present in test data point [True]
# 297 Text feature [harbor] present in test data point [True]
# 298 Text feature [negative] present in test data point [True]
# 299 Text feature [3e] present in test data point [True]
# 300 Text feature [40] present in test data point [True]
# 301 Text feature [distinct] present in test data point [True]
# 302 Text feature [variety] present in test data point [True]
# 304 Text feature [directly] present in test data point [True]
# 305 Text feature [initial] present in test data point [True]
# 306 Text feature [provided] present in test data point [True]
# 308 Text feature [transduction] present in test data point [True]
# 310 Text feature [software] present in test data point [True]
# 311 Text feature [patient] present in test data point [True]
# 312 Text feature [characterized] present in test data point [True]
# 313 Text feature [significant] present in test data point [True]
# 314 Text feature [regulated] present in test data point [True]
# 315 Text feature [day] present in test data point [True]
# 319 Text feature [50] present in test data point [True]
# 320 Text feature [sodium] present in test data point [True]
# 323 Text feature [frequently] present in test data point [True]
# 324 Text feature [17] present in test data point [True]
# 325 Text feature [14] present in test data point [True]
# 326 Text feature [indicated] present in test data point [True]
# 329 Text feature [highly] present in test data point [True]
# 331 Text feature [containing] present in test data point [True]
# 332 Text feature [caused] present in test data point [True]
# 333 Text feature [standard] present in test data point [True]
# 334 Text feature [level] present in test data point [True]
# 335 Text feature [major] present in test data point [True]
# 336 Text feature [22] present in test data point [True]
# 337 Text feature [later] present in test data point [True]
# 338 Text feature [key] present in test data point [True]
# 340 Text feature [levels] present in test data point [True]
# 341 Text feature [oncogene] present in test data point [True]
# 342 Text feature [sample] present in test data point [True]
# 343 Text feature [30] present in test data point [True]
# 346 Text feature [vector] present in test data point [True]
# 347 Text feature [developed] present in test data point [True]
# 348 Text feature [activity] present in test data point [True]
# 349 Text feature [progression] present in test data point [True]
# 350 Text feature [concentration] present in test data point [True]
# 351 Text feature [increasing] present in test data point [True]
# 352 Text feature [open] present in test data point [True]
# 354 Text feature [differences] present in test data point [True]
# 355 Text feature [even] present in test data point [True]
# 357 Text feature [important] present in test data point [True]
# 359 Text feature [cellular] present in test data point [True]
# 361 Text feature [introduction] present in test data point [True]
# 364 Text feature [leads] present in test data point [True]
# 366 Text feature [agents] present in test data point [True]
# 367 Text feature [established] present in test data point [True]
# 368 Text feature [subsequently] present in test data point [True]
# 369 Text feature [novel] present in test data point [True]
# 370 Text feature [fold] present in test data point [True]
# 371 Text feature [carcinoma] present in test data point [True]
# 372 Text feature [would] present in test data point [True]
# 373 Text feature [disease] present in test data point [True]
# 375 Text feature [stable] present in test data point [True]
# 376 Text feature [rate] present in test data point [True]
# 377 Text feature [completely] present in test data point [True]
# 378 Text feature [used] present in test data point [True]
# 379 Text feature [therapy] present in test data point [True]
# 380 Text feature [importance] present in test data point [True]
# 381 Text feature [support] present in test data point [True]
# 382 Text feature [line] present in test data point [True]
# 384 Text feature [regulation] present in test data point [True]
# 385 Text feature [complete] present in test data point [True]
# 387 Text feature [primary] present in test data point [True]
# 388 Text feature [strongly] present in test data point [True]
# 389 Text feature [data] present in test data point [True]
# 390 Text feature [much] present in test data point [True]
# 391 Text feature [2a] present in test data point [True]
# 394 Text feature [16] present in test data point [True]
# 395 Text feature [molecule] present in test data point [True]
# 401 Text feature [serine] present in test data point [True]
# 404 Text feature [doses] present in test data point [True]
# 405 Text feature [investigated] present in test data point [True]
# 409 Text feature [approval] present in test data point [True]
# 410 Text feature [therefore] present in test data point [True]
# 412 Text feature [effectively] present in test data point [True]
# 414 Text feature [dramatic] present in test data point [True]
# 415 Text feature [clinically] present in test data point [True]
# 416 Text feature [low] present in test data point [True]
# 419 Text feature [specimens] present in test data point [True]
# 420 Text feature [additionally] present in test data point [True]
# 421 Text feature [targets] present in test data point [True]
# 423 Text feature [s3] present in test data point [True]
# 424 Text feature [epithelial] present in test data point [True]
# 425 Text feature [manner] present in test data point [True]
# 428 Text feature [greater] present in test data point [True]
# 429 Text feature [mapk] present in test data point [True]
# 430 Text feature [stably] present in test data point [True]
# 431 Text feature [moreover] present in test data point [True]
# 433 Text feature [size] present in test data point [True]
# 434 Text feature [control] present in test data point [True]
# 435 Text feature [institute] present in test data point [True]
# 437 Text feature [conformation] present in test data point [True]
# 438 Text feature [tissues] present in test data point [True]
# 439 Text feature [remains] present in test data point [True]
# 446 Text feature [28] present in test data point [True]
# 449 Text feature [generation] present in test data point [True]
# 450 Text feature [form] present in test data point [True]
# 451 Text feature [identify] present in test data point [True]
# 452 Text feature [stimulated] present in test data point [True]
# 454 Text feature [sensitivity] present in test data point [True]
# 455 Text feature [observation] present in test data point [True]
# 456 Text feature [subjected] present in test data point [True]
# 460 Text feature [2d] present in test data point [True]
# 461 Text feature [difference] present in test data point [True]
# 462 Text feature [oncogenes] present in test data point [True]
# 463 Text feature [almost] present in test data point [True]
# 464 Text feature [designed] present in test data point [True]
# 465 Text feature [coding] present in test data point [True]
# 467 Text feature [failed] present in test data point [True]
# 468 Text feature [dmem] present in test data point [True]
# 469 Text feature [design] present in test data point [True]
# 470 Text feature [observations] present in test data point [True]
# 471 Text feature [11] present in test data point [True]
# 472 Text feature [fixed] present in test data point [True]
# 473 Text feature [endogenous] present in test data point [True]
# 474 Text feature [associated] present in test data point [True]
# 476 Text feature [trial] present in test data point [True]
# 477 Text feature [selective] present in test data point [True]
# 478 Text feature [combination] present in test data point [True]
# 479 Text feature [multiple] present in test data point [True]
# 480 Text feature [s1] present in test data point [True]
# 481 Text feature [stained] present in test data point [True]
# 485 Text feature [cases] present in test data point [True]
# 486 Text feature [type] present in test data point [True]
# 487 Text feature [comparable] present in test data point [True]
# 488 Text feature [five] present in test data point [True]
# 489 Text feature [provide] present in test data point [True]
# 490 Text feature [hypothesized] present in test data point [True]
# 491 Text feature [investigate] present in test data point [True]
# 492 Text feature [4d] present in test data point [True]
# 493 Text feature [yet] present in test data point [True]
# 495 Text feature [32] present in test data point [True]
# 496 Text feature [finding] present in test data point [True]
# 497 Text feature [include] present in test data point [True]
# 499 Text feature [exhibited] present in test data point [True]
# 500 Text feature [able] present in test data point [True]
# 504 Text feature [upon] present in test data point [True]
# 505 Text feature [anchorage] present in test data point [True]
# 507 Text feature [response] present in test data point [True]
# 509 Text feature [requires] present in test data point [True]
# 510 Text feature [long] present in test data point [True]
# 511 Text feature [biological] present in test data point [True]
# 512 Text feature [resistant] present in test data point [True]
# 514 Text feature [starved] present in test data point [True]
# 516 Text feature [bovine] present in test data point [True]
# 517 Text feature [alone] present in test data point [True]
# 518 Text feature [driven] present in test data point [True]
# 520 Text feature [range] present in test data point [True]
# 521 Text feature [understanding] present in test data point [True]
# 523 Text feature [carried] present in test data point [True]
# 525 Text feature [shows] present in test data point [True]
# 526 Text feature [ca] present in test data point [True]
# 529 Text feature [number] present in test data point [True]
# 531 Text feature [enhance] present in test data point [True]
# 532 Text feature [effect] present in test data point [True]
# 533 Text feature [corresponding] present in test data point [True]
# 534 Text feature [work] present in test data point [True]
# 539 Text feature [80] present in test data point [True]
# 541 Text feature [s5] present in test data point [True]
# 542 Text feature [drive] present in test data point [True]
# 543 Text feature [required] present in test data point [True]
# 544 Text feature [many] present in test data point [True]
# 546 Text feature [future] present in test data point [True]
# 547 Text feature [sites] present in test data point [True]
# 549 Text feature [amplification] present in test data point [True]
# 550 Text feature [potent] present in test data point [True]
# 552 Text feature [prolonged] present in test data point [True]
# 553 Text feature [order] present in test data point [True]
# 554 Text feature [still] present in test data point [True]
# 555 Text feature [il] present in test data point [True]
# 557 Text feature [period] present in test data point [True]
# 558 Text feature [72] present in test data point [True]
# 562 Text feature [extracted] present in test data point [True]
# 563 Text feature [blocked] present in test data point [True]
# 566 Text feature [phase] present in test data point [True]
# 567 Text feature [board] present in test data point [True]
# 568 Text feature [metastatic] present in test data point [True]
# 569 Text feature [adenocarcinoma] present in test data point [True]
# 571 Text feature [biochemical] present in test data point [True]
# 572 Text feature [promoting] present in test data point [True]
# 573 Text feature [along] present in test data point [True]
# 574 Text feature [nsclc] present in test data point [True]
# 577 Text feature [current] present in test data point [True]
# 579 Text feature [2e] present in test data point [True]
# 581 Text feature [wild] present in test data point [True]
# 582 Text feature [frequent] present in test data point [True]
# 583 Text feature [signal] present in test data point [True]
# 585 Text feature [event] present in test data point [True]
# 587 Text feature [dmso] present in test data point [True]
# 589 Text feature [summary] present in test data point [True]
# 590 Text feature [egfr] present in test data point [True]
# 592 Text feature [review] present in test data point [True]
# 593 Text feature [limited] present in test data point [True]
# 595 Text feature [subsequent] present in test data point [True]
# 596 Text feature [capable] present in test data point [True]
# 599 Text feature [inhibiting] present in test data point [True]
# 600 Text feature [crystal] present in test data point [True]
# 601 Text feature [located] present in test data point [True]
# 602 Text feature [least] present in test data point [True]
# 604 Text feature [roche] present in test data point [True]
# 609 Text feature [subset] present in test data point [True]
# 611 Text feature [extracellular] present in test data point [True]
# 612 Text feature [33] present in test data point [True]
# 613 Text feature [status] present in test data point [True]
# 615 Text feature [health] present in test data point [True]
# 616 Text feature [initiated] present in test data point [True]
# 618 Text feature [portion] present in test data point [True]
# 620 Text feature [context] present in test data point [True]
# 621 Text feature [frequency] present in test data point [True]
# 622 Text feature [majority] present in test data point [True]
# 624 Text feature [via] present in test data point [True]
# 625 Text feature [overall] present in test data point [True]
# 626 Text feature [44] present in test data point [True]
# 629 Text feature [critical] present in test data point [True]
# 630 Text feature [independently] present in test data point [True]
# 631 Text feature [23] present in test data point [True]
# 633 Text feature [erk] present in test data point [True]
# 638 Text feature [transfection] present in test data point [True]
# 640 Text feature [constructs] present in test data point [True]
# 641 Text feature [sufficient] present in test data point [True]
# 643 Text feature [play] present in test data point [True]
# 646 Text feature [treating] present in test data point [True]
# 647 Text feature [threonine] present in test data point [True]
# 651 Text feature [comparison] present in test data point [True]
# 653 Text feature [exogenous] present in test data point [True]
# 654 Text feature [nm] present in test data point [True]
# 656 Text feature [known] present in test data point [True]
# 657 Text feature [viral] present in test data point [True]
# 660 Text feature [21] present in test data point [True]
# 661 Text feature [formation] present in test data point [True]
# 662 Text feature [characterize] present in test data point [True]
# 663 Text feature [note] present in test data point [True]
# 665 Text feature [inhibitory] present in test data point [True]
# 666 Text feature [transiently] present in test data point [True]
# 668 Text feature [vivo] present in test data point [True]
# 671 Text feature [transforming] present in test data point [True]
# 672 Text feature [model] present in test data point [True]
# 673 Text feature [adjacent] present in test data point [True]
# 674 Text feature [targeting] present in test data point [True]
# 676 Text feature [left] present in test data point [True]
# 677 Text feature [transferred] present in test data point [True]
# 678 Text feature [right] present in test data point [True]
# 679 Text feature [extent] present in test data point [True]
# 680 Text feature [appear] present in test data point [True]
# 682 Text feature [forms] present in test data point [True]
# 683 Text feature [ii] present in test data point [True]
# 685 Text feature [buffer] present in test data point [True]
# 686 Text feature [fact] present in test data point [True]
# 687 Text feature [demonstrating] present in test data point [True]
# 690 Text feature [near] present in test data point [True]
# 691 Text feature [repeated] present in test data point [True]
# 692 Text feature [since] present in test data point [True]
# 693 Text feature [sections] present in test data point [True]
# 694 Text feature [exposure] present in test data point [True]
# 695 Text feature [protein] present in test data point [True]
# 696 Text feature [amplified] present in test data point [True]
# 697 Text feature [end] present in test data point [True]
# 698 Text feature [acid] present in test data point [True]
# 700 Text feature [use] present in test data point [True]
# 701 Text feature [certain] present in test data point [True]
# 703 Text feature [regulate] present in test data point [True]
# 706 Text feature [like] present in test data point [True]
# 707 Text feature [density] present in test data point [True]
# 708 Text feature [appears] present in test data point [True]
# 711 Text feature [notably] present in test data point [True]
# 714 Text feature [membrane] present in test data point [True]
# 716 Text feature [3t3] present in test data point [True]
# 717 Text feature [strategies] present in test data point [True]
# 719 Text feature [occurs] present in test data point [True]
# 722 Text feature [stage] present in test data point [True]
# 723 Text feature [advantage] present in test data point [True]
# 724 Text feature [tested] present in test data point [True]
# 725 Text feature [region] present in test data point [True]
# 728 Text feature [every] present in test data point [True]
# 729 Text feature [formed] present in test data point [True]
# 730 Text feature [products] present in test data point [True]
# 734 Text feature [implications] present in test data point [True]
# 740 Text feature [modest] present in test data point [True]
# 743 Text feature [short] present in test data point [True]
# 745 Text feature [reduced] present in test data point [True]
# 746 Text feature [times] present in test data point [True]
# 749 Text feature [blocks] present in test data point [True]
# 750 Text feature [characterization] present in test data point [True]
# 751 Text feature [sds] present in test data point [True]
# 754 Text feature [hematoxylin] present in test data point [True]
# 755 Text feature [providing] present in test data point [True]
# 756 Text feature [direct] present in test data point [True]
# 758 Text feature [diseases] present in test data point [True]
# 760 Text feature [genes] present in test data point [True]
# 762 Text feature [wide] present in test data point [True]
# 763 Text feature [media] present in test data point [True]
# 765 Text feature [block] present in test data point [True]
# 766 Text feature [proteins] present in test data point [True]
# 768 Text feature [screen] present in test data point [True]
# 770 Text feature [expected] present in test data point [True]
# 771 Text feature [regulates] present in test data point [True]
# 775 Text feature [gain] present in test data point [True]
# 776 Text feature [staining] present in test data point [True]
# 777 Text feature [necessary] present in test data point [True]
# 782 Text feature [become] present in test data point [True]
# 783 Text feature [29] present in test data point [True]
# 784 Text feature [methods] present in test data point [True]
# 785 Text feature [immunohistochemistry] present in test data point [True]
# 786 Text feature [slightly] present in test data point [True]
# 787 Text feature [therapeutics] present in test data point [True]
# 793 Text feature [pattern] present in test data point [True]
# 799 Text feature [briefly] present in test data point [True]
# 801 Text feature [blotting] present in test data point [True]
# 802 Text feature [immunoblot] present in test data point [True]
# 804 Text feature [histological] present in test data point [True]
# 806 Text feature [inactive] present in test data point [True]
# 807 Text feature [marked] present in test data point [True]
# 808 Text feature [importantly] present in test data point [True]
# 809 Text feature [consistently] present in test data point [True]
# 810 Text feature [detection] present in test data point [True]
# 811 Text feature [preclinical] present in test data point [True]
# 815 Text feature [37] present in test data point [True]
# 817 Text feature [fluorescent] present in test data point [True]
# 818 Text feature [1e] present in test data point [True]
# 819 Text feature [extraction] present in test data point [True]
# 821 Text feature [allowing] present in test data point [True]
# 822 Text feature [values] present in test data point [True]
# 827 Text feature [deletion] present in test data point [True]
# 829 Text feature [processes] present in test data point [True]
# 832 Text feature [mice] present in test data point [True]
# 833 Text feature [acquired] present in test data point [True]
# 835 Text feature [clones] present in test data point [True]
# 837 Text feature [closely] present in test data point [True]
# 839 Text feature [fetal] present in test data point [True]
# 841 Text feature [site] present in test data point [True]
# 843 Text feature [involved] present in test data point [True]
# 844 Text feature [41] present in test data point [True]
# 846 Text feature [3f] present in test data point [True]
# 848 Text feature [provides] present in test data point [True]
# 850 Text feature [induce] present in test data point [True]
# 852 Text feature [median] present in test data point [True]
# 853 Text feature [independence] present in test data point [True]
# 854 Text feature [efforts] present in test data point [True]
# 856 Text feature [phosphorylated] present in test data point [True]
# 858 Text feature [reports] present in test data point [True]
# 862 Text feature [mixed] present in test data point [True]
# 865 Text feature [understand] present in test data point [True]
# 867 Text feature [among] present in test data point [True]
# 869 Text feature [blocking] present in test data point [True]
# 870 Text feature [schematic] present in test data point [True]
# 871 Text feature [removed] present in test data point [True]
# 872 Text feature [peroxidase] present in test data point [True]
# 881 Text feature [roles] present in test data point [True]
# 882 Text feature [05] present in test data point [True]
# 883 Text feature [probed] present in test data point [True]
# 886 Text feature [equivalent] present in test data point [True]
# 887 Text feature [notion] present in test data point [True]
# 888 Text feature [amino] present in test data point [True]
# 889 Text feature [full] present in test data point [True]
# 893 Text feature [rank] present in test data point [True]
# 896 Text feature [36] present in test data point [True]
# 897 Text feature [months] present in test data point [True]
# 900 Text feature [cloned] present in test data point [True]
# 902 Text feature [phenotype] present in test data point [True]
# 903 Text feature [plus] present in test data point [True]
# 904 Text feature [adding] present in test data point [True]
# 908 Text feature [national] present in test data point [True]
# 911 Text feature [exons] present in test data point [True]
# 912 Text feature [given] present in test data point [True]
# 915 Text feature [onto] present in test data point [True]
# 916 Text feature [acute] present in test data point [True]
# 918 Text feature [34] present in test data point [True]
# 920 Text feature [homology] present in test data point [True]
# 923 Text feature [events] present in test data point [True]
# 925 Text feature [see] present in test data point [True]
# 926 Text feature [substantial] present in test data point [True]
# 927 Text feature [insensitive] present in test data point [True]
# 928 Text feature [akt] present in test data point [True]
# 930 Text feature [indicates] present in test data point [True]
# 935 Text feature [hypothesis] present in test data point [True]
# 936 Text feature [potentially] present in test data point [True]
# 938 Text feature [5a] present in test data point [True]
# 939 Text feature [second] present in test data point [True]
# 942 Text feature [based] present in test data point [True]
# 946 Text feature [components] present in test data point [True]
# 947 Text feature [rates] present in test data point [True]
# 948 Text feature [image] present in test data point [True]
# 951 Text feature [leukemia] present in test data point [True]
# 955 Text feature [primarily] present in test data point [True]
# 957 Text feature [promoted] present in test data point [True]
# 961 Text feature [residues] present in test data point [True]
# 965 Text feature [bone] present in test data point [True]
# 967 Text feature [system] present in test data point [True]
# 970 Text feature [markedly] present in test data point [True]
# 972 Text feature [length] present in test data point [True]
# 973 Text feature [reveals] present in test data point [True]
# 975 Text feature [alterations] present in test data point [True]
# 980 Text feature [association] present in test data point [True]
# 982 Text feature [bd] present in test data point [True]
# 983 Text feature [rapid] present in test data point [True]
# 984 Text feature [resistance] present in test data point [True]
# 985 Text feature [intrinsic] present in test data point [True]
# 986 Text feature [supported] present in test data point [True]
# 990 Text feature [wells] present in test data point [True]
# 992 Text feature [homolog] present in test data point [True]
# 993 Text feature [partial] present in test data point [True]
# 994 Text feature [genetic] present in test data point [True]
# 997 Text feature [view] present in test data point [True]
# 999 Text feature [knowledge] present in test data point [True]
# Out of the top  1000  features  666 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() 
# here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_,eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0474286089263039
# for alpha = 11
# Log Loss : 1.0348684713056395
# for alpha = 15
# Log Loss : 1.0348137658959249
# for alpha = 21
# Log Loss : 1.039255326818707
# for alpha = 31
# Log Loss : 1.0602486779752058
# for alpha = 41
# Log Loss : 1.074746095927293
# for alpha = 51
# Log Loss : 1.088366729813586
# for alpha = 99
# Log Loss : 1.1201745444339248
# For values of best alpha =  15 The train log loss is: 0.6873365470807438
# For values of best alpha =  15 The cross validation log loss is: 1.0348137658959249
# For values of best alpha =  15 The test log loss is: 1.1578838432501455

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() 
# here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0348137658959249
# Number of mis-classified points : 0.37679083094555876
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 2
# Actual Class : 9
# The  15  nearest neighbours of the test points belongs to classes [7 9 7 7 7 7 7 7 7 2 7 7 7 7 7]
# Fequency of nearest points : Counter({7: 13, 9: 1, 2: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 1
# the k value for knn is 15 and the nearest neighbours of the test points belongs to classes [4 4 4 4 4 4 4 4 4 4 4 4 4 4 4]
# Fequency of nearest points : Counter({4: 15})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3163168645322734
# for alpha = 1e-05
# Log Loss : 1.3061109119277405
# for alpha = 0.0001
# Log Loss : 1.0850246689124647
# for alpha = 0.001
# Log Loss : 1.0194137562381673
# for alpha = 0.01
# Log Loss : 1.073429646971071
# for alpha = 0.1
# Log Loss : 1.2439367347193013
# for alpha = 1
# Log Loss : 1.4589818080085502
# for alpha = 10
# Log Loss : 1.4991564406210534
# for alpha = 100
# Log Loss : 1.5036836309393284
# For values of best alpha =  0.001 The train log loss is: 0.48179879763324274
# For values of best alpha =  0.001 The cross validation log loss is: 1.0194137562381673
# For values of best alpha =  0.001 The test log loss is: 1.1284348289741455

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0194137562381673
# Number of mis-classified points : 0.35959885386819485
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0173 0.0259 0.0072 0.0246 0.0148 0.01   0.5982 0.0096 0.2924]]
# Actual Class : 9
# --------------------------------------------------
# 17 Text feature [constitutive] present in test data point [True]
# 40 Text feature [constitutively] present in test data point [True]
# 117 Text feature [activated] present in test data point [True]
# 131 Text feature [activation] present in test data point [True]
# 144 Text feature [serum] present in test data point [True]
# 147 Text feature [oncogenic] present in test data point [True]
# 152 Text feature [expressing] present in test data point [True]
# 173 Text feature [murine] present in test data point [True]
# 362 Text feature [carpten] present in test data point [True]
# 399 Text feature [inhibitor] present in test data point [True]
# 414 Text feature [transformed] present in test data point [True]
# 426 Text feature [transduced] present in test data point [True]
# 476 Text feature [magnification] present in test data point [True]
# 501 Text feature [kinase] present in test data point [True]
# 507 Text feature [lung] present in test data point [True]
# 523 Text feature [phosphorylation] present in test data point [True]
# 583 Text feature [concentrations] present in test data point [True]
# 590 Text feature [h1975] present in test data point [True]
# 656 Text feature [activating] present in test data point [True]
# 661 Text feature [erk] present in test data point [True]
# 669 Text feature [tpa] present in test data point [True]
# 677 Text feature [egfr] present in test data point [True]
# 700 Text feature [houston] present in test data point [True]
# 704 Text feature [activate] present in test data point [True]
# 828 Text feature [retroviral] present in test data point [True]
# 885 Text feature [gsk3] present in test data point [True]
# 896 Text feature [pleckstrin] present in test data point [True]
# 901 Text feature [e17k] present in test data point [True]
# 917 Text feature [inhibited] present in test data point [True]
# 923 Text feature [h1993] present in test data point [True]
# 951 Text feature [tyrosine] present in test data point [True]
# 958 Text feature [receptor] present in test data point [True]
# Out of the top  1000  features  32 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 55
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0226 0.0615 0.0235 0.0274 0.0259 0.0222 0.8034 0.0102 0.0034]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [constitutive] present in test data point [True]
# 40 Text feature [constitutively] present in test data point [True]
# 117 Text feature [activated] present in test data point [True]
# 121 Text feature [downstream] present in test data point [True]
# 131 Text feature [activation] present in test data point [True]
# 133 Text feature [technology] present in test data point [True]
# 139 Text feature [allosterically] present in test data point [True]
# 144 Text feature [serum] present in test data point [True]
# 147 Text feature [oncogenic] present in test data point [True]
# 152 Text feature [expressing] present in test data point [True]
# 165 Text feature [dabrafenib] present in test data point [True]
# 172 Text feature [dramatic] present in test data point [True]
# 173 Text feature [murine] present in test data point [True]
# 192 Text feature [ligand] present in test data point [True]
# 227 Text feature [il] present in test data point [True]
# 231 Text feature [oncogene] present in test data point [True]
# 236 Text feature [3t3] present in test data point [True]
# 272 Text feature [phospho] present in test data point [True]
# 301 Text feature [isozyme] present in test data point [True]
# 308 Text feature [transformation] present in test data point [True]
# 325 Text feature [thymoma] present in test data point [True]
# 386 Text feature [2206] present in test data point [True]
# 399 Text feature [inhibitor] present in test data point [True]
# 403 Text feature [extracellular] present in test data point [True]
# 405 Text feature [anchorage] present in test data point [True]
# 476 Text feature [magnification] present in test data point [True]
# 481 Text feature [oncogenes] present in test data point [True]
# Out of the top  500  features  27 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.239853377239711
# for alpha = 1e-05
# Log Loss : 1.2447574096570924
# for alpha = 0.0001
# Log Loss : 1.078358297705058
# for alpha = 0.001
# Log Loss : 1.0281776358658814
# for alpha = 0.01
# Log Loss : 1.0738831548893732
# for alpha = 0.1
# Log Loss : 1.2289677392052551
# for alpha = 1
# Log Loss : 1.4198223843220699
# For values of best alpha =  0.001 The train log loss is: 0.4788832442699485
# For values of best alpha =  0.001 The cross validation log loss is: 1.0281776358658814
# For values of best alpha =  0.001 The test log loss is: 1.128945007105061

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0281776358658814
# Number of mis-classified points : 0.3524355300859599
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 100
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index],
                     no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0563 0.0429 0.0135 0.7534 0.0317 0.0336 0.0571 0.0052 0.0064]]
# Actual Class : 1
# --------------------------------------------------
# 211 Text feature [nonsense] present in test data point [True]
# 328 Text feature [obscure] present in test data point [True]
# 367 Text feature [suppressor] present in test data point [True]
# 476 Text feature [mss] present in test data point [True]
# 478 Text feature [localization] present in test data point [True]
# 528 Text feature [nuclear] present in test data point [True]
# 558 Text feature [missense] present in test data point [True]
# 647 Text feature [mammalian] present in test data point [True]
# 750 Text feature [spectra] present in test data point [True]
# 827 Text feature [instability] present in test data point [True]
# 843 Text feature [yeast] present in test data point [True]
# 881 Text feature [glu] present in test data point [True]
# 915 Text feature [maintenance] present in test data point [True]
# 921 Text feature [impairs] present in test data point [True]
# 941 Text feature [renal] present in test data point [True]
# 965 Text feature [iii] present in test data point [True]
# Out of the top  1000  features  16 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 1
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index],
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0176 0.0254 0.0058 0.0252 0.0126 0.0087 0.6058 0.0174 0.2815]]
# Actual Class : 9
# --------------------------------------------------
# 59 Text feature [constitutive] present in test data point [True]
# 75 Text feature [constitutively] present in test data point [True]
# 125 Text feature [expressing] present in test data point [True]
# 130 Text feature [activated] present in test data point [True]
# 132 Text feature [activation] present in test data point [True]
# 153 Text feature [oncogenic] present in test data point [True]
# 175 Text feature [serum] present in test data point [True]
# 225 Text feature [murine] present in test data point [True]
# 275 Text feature [inhibitor] present in test data point [True]
# 284 Text feature [transformed] present in test data point [True]
# 291 Text feature [carpten] present in test data point [True]
# 317 Text feature [kinase] present in test data point [True]
# 341 Text feature [phosphorylation] present in test data point [True]
# 351 Text feature [transduced] present in test data point [True]
# 423 Text feature [activating] present in test data point [True]
# 438 Text feature [concentrations] present in test data point [True]
# 476 Text feature [magnification] present in test data point [True]
# 556 Text feature [activate] present in test data point [True]
# 562 Text feature [lung] present in test data point [True]
# 577 Text feature [inhibited] present in test data point [True]
# 627 Text feature [tpa] present in test data point [True]
# 667 Text feature [e17k] present in test data point [True]
# 680 Text feature [hairpin] present in test data point [True]
# 683 Text feature [h1975] present in test data point [True]
# 695 Text feature [retroviral] present in test data point [True]
# 704 Text feature [erk] present in test data point [True]
# 711 Text feature [houston] present in test data point [True]
# 758 Text feature [pleckstrin] present in test data point [True]
# 764 Text feature [egfr] present in test data point [True]
# 817 Text feature [signaling] present in test data point [True]
# 868 Text feature [tyrosine] present in test data point [True]
# 925 Text feature [gsk3] present in test data point [True]
# 937 Text feature [virus] present in test data point [True]
# 949 Text feature [3e] present in test data point [True]
# 954 Text feature [receptor] present in test data point [True]
# 960 Text feature [dependence] present in test data point [True]
# 995 Text feature [2f] present in test data point [True]
# Out of the top  1000  features  37 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.3258009886080453
# for C = 0.0001
# Log Loss : 1.267708515897758
# for C = 0.001
# Log Loss : 1.0951655401583056
# for C = 0.01
# Log Loss : 1.1184282911477268
# for C = 0.1
# Log Loss : 1.2339419640014166
# for C = 1
# Log Loss : 1.5040188722434946
# for C = 10
# Log Loss : 1.5044242130926637
# for C = 100
# Log Loss : 1.5044252611208695
# For values of best alpha =  0.001 The train log loss is: 0.5227755684000184
# For values of best alpha =  0.001 The cross validation log loss is: 1.0951655401583056
# For values of best alpha =  0.001 The test log loss is: 1.2229689375584385

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0951655401583056
# Number of mis-classified points : 0.34097421203438394
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index],
                     no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.0771 0.0464 0.0107 0.0295 0.0424 0.0257 0.2571 0.0067 0.5046]]
# Actual Class : 9
# --------------------------------------------------
# 557 Text feature [coated] present in test data point [True]
# 589 Text feature [aberrantly] present in test data point [True]
# 946 Text feature [aberrant] present in test data point [True]
# 974 Text feature [preference] present in test data point [True]
# Out of the top  1000  features  4 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 31
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0727 0.5053 0.0163 0.0721 0.0413 0.0251 0.2544 0.0059 0.007 ]]
# Actual Class : 7
# --------------------------------------------------
# 75 Text feature [moreno] present in test data point [True]
# 123 Text feature [287] present in test data point [True]
# 145 Text feature [cargo] present in test data point [True]
# 321 Text feature [cellgro] present in test data point [True]
# 323 Text feature [coupled] present in test data point [True]
# 387 Text feature [diehl] present in test data point [True]
# 537 Text feature [stage] present in test data point [True]
# 616 Text feature [demonstrates] present in test data point [True]
# 646 Text feature [26s] present in test data point [True]
# 657 Text feature [soybean] present in test data point [True]
# 669 Text feature [roberts] present in test data point [True]
# 671 Text feature [recognized] present in test data point [True]
# 683 Text feature [unrestricted] present in test data point [True]
# 800 Text feature [patients] present in test data point [True]
# 821 Text feature [marais] present in test data point [True]
# 825 Text feature [compartment] present in test data point [True]
# 837 Text feature [achieved] present in test data point [True]
# 879 Text feature [smith] present in test data point [True]
# 881 Text feature [garnett] present in test data point [True]
# Out of the top  1000  features  19 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', 
      alpha[int(best_alpha/2)], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', 
      alpha[int(best_alpha/2)], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', 
      alpha[int(best_alpha/2)], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2315184891128559
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1419021567971392
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2154378053522112
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1321344387971637
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.203251862538601
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.1269220636266393
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1982850351411938
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1212541373522844
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1968436643041689
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.1195595629475725
# For values of best estimator =  2000 The train log loss is: 0.5831141097829241
# For values of best estimator =  2000 The cross validation log loss is: 1.1195595629475725
# For values of best estimator =  2000 The test log loss is: 1.1734459953456757

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1195595629475725
# Number of mis-classified points : 0.3868194842406877
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.041  0.0514 0.0142 0.0362 0.0305 0.0283 0.4482 0.09   0.2601]]
# Actual Class : 9
# --------------------------------------------------
# 0 Text feature [activating] present in test data point [True]
# 1 Text feature [kinase] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [constitutive] present in test data point [True]
# 5 Text feature [tyrosine] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [oncogenic] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [inhibitor] present in test data point [True]
# 13 Text feature [phosphorylation] present in test data point [True]
# 14 Text feature [signaling] present in test data point [True]
# 15 Text feature [loss] present in test data point [True]
# 19 Text feature [trials] present in test data point [True]
# 20 Text feature [inhibited] present in test data point [True]
# 23 Text feature [expressing] present in test data point [True]
# 24 Text feature [constitutively] present in test data point [True]
# 25 Text feature [receptor] present in test data point [True]
# 26 Text feature [protein] present in test data point [True]
# 27 Text feature [proliferation] present in test data point [True]
# 30 Text feature [growth] present in test data point [True]
# 32 Text feature [drug] present in test data point [True]
# 34 Text feature [akt] present in test data point [True]
# 36 Text feature [cells] present in test data point [True]
# 38 Text feature [clinical] present in test data point [True]
# 41 Text feature [egfr] present in test data point [True]
# 43 Text feature [inhibition] present in test data point [True]
# 46 Text feature [erk] present in test data point [True]
# 47 Text feature [nsclc] present in test data point [True]
# 48 Text feature [survival] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 54 Text feature [defective] present in test data point [True]
# 56 Text feature [proteins] present in test data point [True]
# 58 Text feature [effective] present in test data point [True]
# 59 Text feature [resistance] present in test data point [True]
# 62 Text feature [functions] present in test data point [True]
# 63 Text feature [active] present in test data point [True]
# 64 Text feature [sensitivity] present in test data point [True]
# 65 Text feature [activate] present in test data point [True]
# 66 Text feature [amplification] present in test data point [True]
# 72 Text feature [variant] present in test data point [True]
# 75 Text feature [treated] present in test data point [True]
# 76 Text feature [factor] present in test data point [True]
# 82 Text feature [lines] present in test data point [True]
# 87 Text feature [dna] present in test data point [True]
# 91 Text feature [ability] present in test data point [True]
# 92 Text feature [serum] present in test data point [True]
# 94 Text feature [binding] present in test data point [True]
# 95 Text feature [lung] present in test data point [True]
# 96 Text feature [kit] present in test data point [True]
# 99 Text feature [abolish] present in test data point [True]
# 108 Text feature [sensitive] present in test data point [True]
# 109 Text feature [response] present in test data point [True]
# 112 Text feature [phosphatase] present in test data point [True]
# 113 Text feature [potential] present in test data point [True]
# 115 Text feature [independent] present in test data point [True]
# 121 Text feature [dose] present in test data point [True]
# 122 Text feature [expression] present in test data point [True]
# 123 Text feature [primary] present in test data point [True]
# 124 Text feature [favor] present in test data point [True]
# 133 Text feature [phosphorylated] present in test data point [True]
# 134 Text feature [pathway] present in test data point [True]
# 139 Text feature [atp] present in test data point [True]
# 145 Text feature [phosphoinositide] present in test data point [True]
# 147 Text feature [tumors] present in test data point [True]
# 149 Text feature [harboring] present in test data point [True]
# 151 Text feature [pi3k] present in test data point [True]
# 156 Text feature [assays] present in test data point [True]
# 163 Text feature [arrest] present in test data point [True]
# 174 Text feature [laboratories] present in test data point [True]
# 178 Text feature [harbor] present in test data point [True]
# 180 Text feature [experiments] present in test data point [True]
# 182 Text feature [sequence] present in test data point [True]
# 183 Text feature [resistant] present in test data point [True]
# 185 Text feature [likely] present in test data point [True]
# 187 Text feature [drugs] present in test data point [True]
# 188 Text feature [wild] present in test data point [True]
# 192 Text feature [stimulation] present in test data point [True]
# 199 Text feature [doses] present in test data point [True]
# 201 Text feature [assay] present in test data point [True]
# 204 Text feature [study] present in test data point [True]
# 206 Text feature [transduced] present in test data point [True]
# 209 Text feature [type] present in test data point [True]
# 212 Text feature [presence] present in test data point [True]
# 216 Text feature [domain] present in test data point [True]
# 221 Text feature [mutant] present in test data point [True]
# 222 Text feature [antibodies] present in test data point [True]
# 223 Text feature [inositol] present in test data point [True]
# 228 Text feature [data] present in test data point [True]
# 229 Text feature [concentrations] present in test data point [True]
# 232 Text feature [one] present in test data point [True]
# 238 Text feature [activity] present in test data point [True]
# 240 Text feature [used] present in test data point [True]
# 244 Text feature [localization] present in test data point [True]
# 245 Text feature [addition] present in test data point [True]
# 250 Text feature [known] present in test data point [True]
# 253 Text feature [detection] present in test data point [True]
# 254 Text feature [interaction] present in test data point [True]
# 256 Text feature [absence] present in test data point [True]
# 259 Text feature [tagged] present in test data point [True]
# 268 Text feature [3b] present in test data point [True]
# 269 Text feature [initial] present in test data point [True]
# 272 Text feature [reduced] present in test data point [True]
# 275 Text feature [bind] present in test data point [True]
# 276 Text feature [hours] present in test data point [True]
# 277 Text feature [positive] present in test data point [True]
# 279 Text feature [effects] present in test data point [True]
# 281 Text feature [11] present in test data point [True]
# 282 Text feature [contrast] present in test data point [True]
# 284 Text feature [common] present in test data point [True]
# 285 Text feature [sequencing] present in test data point [True]
# 287 Text feature [mutants] present in test data point [True]
# 295 Text feature [results] present in test data point [True]
# 297 Text feature [vitro] present in test data point [True]
# 298 Text feature [150] present in test data point [True]
# 302 Text feature [anti] present in test data point [True]
# 303 Text feature [tissue] present in test data point [True]
# 308 Text feature [12] present in test data point [True]
# 309 Text feature [case] present in test data point [True]
# 310 Text feature [culture] present in test data point [True]
# 314 Text feature [total] present in test data point [True]
# 315 Text feature [conformation] present in test data point [True]
# 317 Text feature [increased] present in test data point [True]
# 320 Text feature [vector] present in test data point [True]
# 323 Text feature [evidence] present in test data point [True]
# 328 Text feature [2b] present in test data point [True]
# 329 Text feature [time] present in test data point [True]
# 331 Text feature [deficient] present in test data point [True]
# 332 Text feature [site] present in test data point [True]
# 334 Text feature [showed] present in test data point [True]
# 340 Text feature [previously] present in test data point [True]
# 341 Text feature [observed] present in test data point [True]
# 343 Text feature [16] present in test data point [True]
# 345 Text feature [membrane] present in test data point [True]
# 346 Text feature [acquired] present in test data point [True]
# 351 Text feature [co] present in test data point [True]
# 352 Text feature [small] present in test data point [True]
# 353 Text feature [mutations] present in test data point [True]
# 354 Text feature [epidermal] present in test data point [True]
# 356 Text feature [cancer] present in test data point [True]
# 357 Text feature [18] present in test data point [True]
# 364 Text feature [methods] present in test data point [True]
# 369 Text feature [agent] present in test data point [True]
# 375 Text feature [catalytic] present in test data point [True]
# 377 Text feature [reported] present in test data point [True]
# 380 Text feature [group] present in test data point [True]
# 384 Text feature [specific] present in test data point [True]
# 389 Text feature [substitution] present in test data point [True]
# 395 Text feature [may] present in test data point [True]
# 397 Text feature [three] present in test data point [True]
# 399 Text feature [13] present in test data point [True]
# 400 Text feature [genetic] present in test data point [True]
# 402 Text feature [figure] present in test data point [True]
# 406 Text feature [genes] present in test data point [True]
# 407 Text feature [mutagenesis] present in test data point [True]
# 408 Text feature [human] present in test data point [True]
# 414 Text feature [define] present in test data point [True]
# 415 Text feature [et] present in test data point [True]
# 416 Text feature [shown] present in test data point [True]
# 417 Text feature [identified] present in test data point [True]
# 418 Text feature [murine] present in test data point [True]
# 422 Text feature [amino] present in test data point [True]
# 429 Text feature [effect] present in test data point [True]
# 436 Text feature [acid] present in test data point [True]
# 437 Text feature [lipid] present in test data point [True]
# 447 Text feature [echelon] present in test data point [True]
# 448 Text feature [different] present in test data point [True]
# 449 Text feature [substrate] present in test data point [True]
# 451 Text feature [competitive] present in test data point [True]
# 452 Text feature [control] present in test data point [True]
# 453 Text feature [discussion] present in test data point [True]
# 455 Text feature [expressed] present in test data point [True]
# 461 Text feature [line] present in test data point [True]
# 462 Text feature [studies] present in test data point [True]
# 467 Text feature [amount] present in test data point [True]
# 468 Text feature [interact] present in test data point [True]
# 469 Text feature [event] present in test data point [True]
# 470 Text feature [currently] present in test data point [True]
# 471 Text feature [somatic] present in test data point [True]
# 472 Text feature [analysis] present in test data point [True]
# 474 Text feature [according] present in test data point [True]
# 478 Text feature [compared] present in test data point [True]
# 482 Text feature [many] present in test data point [True]
# 483 Text feature [10] present in test data point [True]
# 484 Text feature [two] present in test data point [True]
# 489 Text feature [levels] present in test data point [True]
# 492 Text feature [least] present in test data point [True]
# 495 Text feature [important] present in test data point [True]
# 498 Text feature [role] present in test data point [True]
# 499 Text feature [certain] present in test data point [True]
# 500 Text feature [obtained] present in test data point [True]
# 501 Text feature [given] present in test data point [True]
# 506 Text feature [involved] present in test data point [True]
# 509 Text feature [containing] present in test data point [True]
# 510 Text feature [gain] present in test data point [True]
# 511 Text feature [significantly] present in test data point [True]
# 512 Text feature [ml] present in test data point [True]
# 514 Text feature [without] present in test data point [True]
# 515 Text feature [3a] present in test data point [True]
# 517 Text feature [western] present in test data point [True]
# 520 Text feature [examined] present in test data point [True]
# 524 Text feature [significance] present in test data point [True]
# 529 Text feature [tested] present in test data point [True]
# 535 Text feature [example] present in test data point [True]
# 536 Text feature [identify] present in test data point [True]
# 537 Text feature [medium] present in test data point [True]
# 538 Text feature [remains] present in test data point [True]
# 539 Text feature [another] present in test data point [True]
# 541 Text feature [next] present in test data point [True]
# 542 Text feature [several] present in test data point [True]
# 548 Text feature [indicated] present in test data point [True]
# 549 Text feature [number] present in test data point [True]
# 550 Text feature [inhibit] present in test data point [True]
# 554 Text feature [would] present in test data point [True]
# 559 Text feature [therefore] present in test data point [True]
# 572 Text feature [appropriate] present in test data point [True]
# 574 Text feature [1a] present in test data point [True]
# 577 Text feature [consistent] present in test data point [True]
# 580 Text feature [however] present in test data point [True]
# 583 Text feature [dependent] present in test data point [True]
# 585 Text feature [critical] present in test data point [True]
# 590 Text feature [cancers] present in test data point [True]
# 591 Text feature [suggesting] present in test data point [True]
# 593 Text feature [whether] present in test data point [True]
# 598 Text feature [wt] present in test data point [True]
# 602 Text feature [generated] present in test data point [True]
# 606 Text feature [development] present in test data point [True]
# 608 Text feature [plasma] present in test data point [True]
# 610 Text feature [included] present in test data point [True]
# 612 Text feature [directed] present in test data point [True]
# 614 Text feature [structural] present in test data point [True]
# 615 Text feature [single] present in test data point [True]
# 617 Text feature [found] present in test data point [True]
# 622 Text feature [36] present in test data point [True]
# 624 Text feature [stop] present in test data point [True]
# 632 Text feature [regulation] present in test data point [True]
# 633 Text feature [signal] present in test data point [True]
# 635 Text feature [furthermore] present in test data point [True]
# 637 Text feature [state] present in test data point [True]
# 638 Text feature [induced] present in test data point [True]
# 639 Text feature [viral] present in test data point [True]
# 641 Text feature [partial] present in test data point [True]
# 644 Text feature [mutation] present in test data point [True]
# 646 Text feature [might] present in test data point [True]
# 647 Text feature [introduction] present in test data point [True]
# 648 Text feature [50] present in test data point [True]
# 652 Text feature [part] present in test data point [True]
# 663 Text feature [also] present in test data point [True]
# 666 Text feature [could] present in test data point [True]
# 668 Text feature [sites] present in test data point [True]
# 669 Text feature [3e] present in test data point [True]
# 671 Text feature [2a] present in test data point [True]
# 673 Text feature [associated] present in test data point [True]
# 674 Text feature [tumor] present in test data point [True]
# 677 Text feature [non] present in test data point [True]
# 681 Text feature [mouse] present in test data point [True]
# 682 Text feature [complex] present in test data point [True]
# 684 Text feature [complete] present in test data point [True]
# 687 Text feature [confirmed] present in test data point [True]
# 688 Text feature [using] present in test data point [True]
# 689 Text feature [ongoing] present in test data point [True]
# 690 Text feature [due] present in test data point [True]
# 691 Text feature [partially] present in test data point [True]
# 693 Text feature [unable] present in test data point [True]
# 696 Text feature [residue] present in test data point [True]
# 700 Text feature [samples] present in test data point [True]
# 704 Text feature [antibody] present in test data point [True]
# 705 Text feature [coding] present in test data point [True]
# 713 Text feature [suppress] present in test data point [True]
# 715 Text feature [target] present in test data point [True]
# 720 Text feature [position] present in test data point [True]
# 730 Text feature [provide] present in test data point [True]
# 732 Text feature [30] present in test data point [True]
# 735 Text feature [alterations] present in test data point [True]
# 736 Text feature [breast] present in test data point [True]
# 739 Text feature [interactions] present in test data point [True]
# 744 Text feature [san] present in test data point [True]
# 745 Text feature [selected] present in test data point [True]
# 746 Text feature [differential] present in test data point [True]
# 747 Text feature [required] present in test data point [True]
# 750 Text feature [buffer] present in test data point [True]
# 752 Text feature [generate] present in test data point [True]
# 753 Text feature [interestingly] present in test data point [True]
# 756 Text feature [lysates] present in test data point [True]
# 759 Text feature [60] present in test data point [True]
# 760 Text feature [following] present in test data point [True]
# 763 Text feature [classes] present in test data point [True]
# 768 Text feature [analyzed] present in test data point [True]
# 770 Text feature [al] present in test data point [True]
# 774 Text feature [eluted] present in test data point [True]
# 775 Text feature [measured] present in test data point [True]
# 778 Text feature [1b] present in test data point [True]
# 781 Text feature [determined] present in test data point [True]
# 785 Text feature [factors] present in test data point [True]
# 787 Text feature [final] present in test data point [True]
# 792 Text feature [result] present in test data point [True]
# 795 Text feature [mediated] present in test data point [True]
# 797 Text feature [seeded] present in test data point [True]
# 799 Text feature [similar] present in test data point [True]
# 801 Text feature [note] present in test data point [True]
# 803 Text feature [targeted] present in test data point [True]
# 808 Text feature [less] present in test data point [True]
# 810 Text feature [signals] present in test data point [True]
# 814 Text feature [second] present in test data point [True]
# 819 Text feature [altered] present in test data point [True]
# 820 Text feature [transfection] present in test data point [True]
# 821 Text feature [free] present in test data point [True]
# 828 Text feature [washed] present in test data point [True]
# 830 Text feature [none] present in test data point [True]
# 832 Text feature [transformed] present in test data point [True]
# 843 Text feature [five] present in test data point [True]
# 845 Text feature [first] present in test data point [True]
# 846 Text feature [test] present in test data point [True]
# 849 Text feature [unknown] present in test data point [True]
# 850 Text feature [published] present in test data point [True]
# 854 Text feature [plates] present in test data point [True]
# 855 Text feature [types] present in test data point [True]
# 861 Text feature [100] present in test data point [True]
# 871 Text feature [even] present in test data point [True]
# 873 Text feature [2c] present in test data point [True]
# 877 Text feature [regulatory] present in test data point [True]
# 880 Text feature [knockout] present in test data point [True]
# 882 Text feature [blue] present in test data point [True]
# 887 Text feature [form] present in test data point [True]
# 890 Text feature [agents] present in test data point [True]
# 895 Text feature [mm] present in test data point [True]
# 899 Text feature [presented] present in test data point [True]
# 900 Text feature [four] present in test data point [True]
# 902 Text feature [show] present in test data point [True]
# 906 Text feature [whole] present in test data point [True]
# 910 Text feature [previous] present in test data point [True]
# 912 Text feature [carrying] present in test data point [True]
# 913 Text feature [plasmids] present in test data point [True]
# 915 Text feature [directly] present in test data point [True]
# 920 Text feature [findings] present in test data point [True]
# 924 Text feature [allele] present in test data point [True]
# 925 Text feature [45] present in test data point [True]
# 927 Text feature [research] present in test data point [True]
# 928 Text feature [assess] present in test data point [True]
# 938 Text feature [fraction] present in test data point [True]
# 942 Text feature [followed] present in test data point [True]
# 945 Text feature [current] present in test data point [True]
# 948 Text feature [groups] present in test data point [True]
# 953 Text feature [components] present in test data point [True]
# 959 Text feature [derived] present in test data point [True]
# 960 Text feature [provided] present in test data point [True]
# 964 Text feature [address] present in test data point [True]
# 969 Text feature [transduction] present in test data point [True]
# 973 Text feature [able] present in test data point [True]
# 974 Text feature [comparable] present in test data point [True]
# 978 Text feature [suggests] present in test data point [True]
# 981 Text feature [make] present in test data point [True]
# 985 Text feature [additional] present in test data point [True]
# 988 Text feature [top] present in test data point [True]
# 991 Text feature [american] present in test data point [True]
# 997 Text feature [greater] present in test data point [True]
# 999 Text feature [concentration] present in test data point [True]
# Out of the top  1000  features  358 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 15
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], 
                     x_test['TEXT'].iloc[test_point_index],
                     x_test['Gene'].iloc[test_point_index],
                     x_test['Variation'].iloc[test_point_index], 
                     no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0603 0.1516 0.0174 0.0379 0.0372 0.0357 0.6442 0.0067 0.0091]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [activating] present in test data point [True]
# 1 Text feature [kinase] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [constitutive] present in test data point [True]
# 5 Text feature [tyrosine] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [oncogenic] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [inhibitor] present in test data point [True]
# 12 Text feature [therapeutic] present in test data point [True]
# 13 Text feature [phosphorylation] present in test data point [True]
# 14 Text feature [signaling] present in test data point [True]
# 15 Text feature [loss] present in test data point [True]
# 16 Text feature [downstream] present in test data point [True]
# 17 Text feature [missense] present in test data point [True]
# 18 Text feature [nonsense] present in test data point [True]
# 19 Text feature [trials] present in test data point [True]
# 20 Text feature [inhibited] present in test data point [True]
# 21 Text feature [therapy] present in test data point [True]
# 23 Text feature [expressing] present in test data point [True]
# 24 Text feature [constitutively] present in test data point [True]
# 25 Text feature [receptor] present in test data point [True]
# 26 Text feature [protein] present in test data point [True]
# 27 Text feature [proliferation] present in test data point [True]
# 28 Text feature [functional] present in test data point [True]
# 30 Text feature [growth] present in test data point [True]
# 32 Text feature [drug] present in test data point [True]
# 34 Text feature [akt] present in test data point [True]
# 36 Text feature [cells] present in test data point [True]
# 37 Text feature [kinases] present in test data point [True]
# 38 Text feature [clinical] present in test data point [True]
# 39 Text feature [pathogenic] present in test data point [True]
# 40 Text feature [advanced] present in test data point [True]
# 42 Text feature [stability] present in test data point [True]
# 43 Text feature [inhibition] present in test data point [True]
# 45 Text feature [patients] present in test data point [True]
# 48 Text feature [survival] present in test data point [True]
# 49 Text feature [variants] present in test data point [True]
# 51 Text feature [phospho] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 56 Text feature [proteins] present in test data point [True]
# 57 Text feature [months] present in test data point [True]
# 58 Text feature [effective] present in test data point [True]
# 59 Text feature [resistance] present in test data point [True]
# 62 Text feature [functions] present in test data point [True]
# 63 Text feature [active] present in test data point [True]
# 64 Text feature [sensitivity] present in test data point [True]
# 65 Text feature [activate] present in test data point [True]
# 66 Text feature [amplification] present in test data point [True]
# 72 Text feature [variant] present in test data point [True]
# 75 Text feature [treated] present in test data point [True]
# 76 Text feature [factor] present in test data point [True]
# 77 Text feature [efficacy] present in test data point [True]
# 80 Text feature [oncogene] present in test data point [True]
# 81 Text feature [transformation] present in test data point [True]
# 82 Text feature [lines] present in test data point [True]
# 84 Text feature [predicted] present in test data point [True]
# 85 Text feature [preclinical] present in test data point [True]
# 86 Text feature [ligand] present in test data point [True]
# 87 Text feature [dna] present in test data point [True]
# 92 Text feature [serum] present in test data point [True]
# 94 Text feature [binding] present in test data point [True]
# 95 Text feature [lung] present in test data point [True]
# 97 Text feature [affected] present in test data point [True]
# 100 Text feature [3t3] present in test data point [True]
# 106 Text feature [daily] present in test data point [True]
# 107 Text feature [nuclear] present in test data point [True]
# 108 Text feature [sensitive] present in test data point [True]
# 109 Text feature [response] present in test data point [True]
# 110 Text feature [patient] present in test data point [True]
# 113 Text feature [potential] present in test data point [True]
# 114 Text feature [interleukin] present in test data point [True]
# 115 Text feature [independent] present in test data point [True]
# 121 Text feature [dose] present in test data point [True]
# 122 Text feature [expression] present in test data point [True]
# 123 Text feature [primary] present in test data point [True]
# 124 Text feature [favor] present in test data point [True]
# 129 Text feature [classified] present in test data point [True]
# 131 Text feature [tki] present in test data point [True]
# 132 Text feature [braf] present in test data point [True]
# 133 Text feature [phosphorylated] present in test data point [True]
# 134 Text feature [pathway] present in test data point [True]
# 135 Text feature [approved] present in test data point [True]
# 138 Text feature [potency] present in test data point [True]
# 139 Text feature [atp] present in test data point [True]
# 144 Text feature [information] present in test data point [True]
# 147 Text feature [tumors] present in test data point [True]
# 148 Text feature [ras] present in test data point [True]
# 149 Text feature [harboring] present in test data point [True]
# 151 Text feature [pi3k] present in test data point [True]
# 153 Text feature [alignments] present in test data point [True]
# 156 Text feature [assays] present in test data point [True]
# 157 Text feature [harbored] present in test data point [True]
# 158 Text feature [alk] present in test data point [True]
# 161 Text feature [chronic] present in test data point [True]
# 163 Text feature [arrest] present in test data point [True]
# 164 Text feature [il] present in test data point [True]
# 170 Text feature [carry] present in test data point [True]
# 172 Text feature [responses] present in test data point [True]
# 173 Text feature [14] present in test data point [True]
# 176 Text feature [expected] present in test data point [True]
# 178 Text feature [harbor] present in test data point [True]
# 180 Text feature [experiments] present in test data point [True]
# 182 Text feature [sequence] present in test data point [True]
# 183 Text feature [resistant] present in test data point [True]
# 185 Text feature [likely] present in test data point [True]
# 187 Text feature [drugs] present in test data point [True]
# 188 Text feature [wild] present in test data point [True]
# 189 Text feature [defects] present in test data point [True]
# 190 Text feature [affect] present in test data point [True]
# 191 Text feature [substitutions] present in test data point [True]
# 192 Text feature [stimulation] present in test data point [True]
# 194 Text feature [stromal] present in test data point [True]
# 196 Text feature [week] present in test data point [True]
# 198 Text feature [probability] present in test data point [True]
# 199 Text feature [doses] present in test data point [True]
# 201 Text feature [assay] present in test data point [True]
# 202 Text feature [classification] present in test data point [True]
# 204 Text feature [study] present in test data point [True]
# 206 Text feature [transduced] present in test data point [True]
# 207 Text feature [hybridization] present in test data point [True]
# 209 Text feature [type] present in test data point [True]
# 212 Text feature [presence] present in test data point [True]
# 216 Text feature [domain] present in test data point [True]
# 217 Text feature [transcriptional] present in test data point [True]
# 219 Text feature [pathways] present in test data point [True]
# 221 Text feature [mutant] present in test data point [True]
# 222 Text feature [antibodies] present in test data point [True]
# 224 Text feature [splice] present in test data point [True]
# 225 Text feature [receptors] present in test data point [True]
# 227 Text feature [molecular] present in test data point [True]
# 228 Text feature [data] present in test data point [True]
# 229 Text feature [concentrations] present in test data point [True]
# 231 Text feature [days] present in test data point [True]
# 232 Text feature [one] present in test data point [True]
# 236 Text feature [recently] present in test data point [True]
# 237 Text feature [large] present in test data point [True]
# 238 Text feature [activity] present in test data point [True]
# 239 Text feature [trans] present in test data point [True]
# 240 Text feature [used] present in test data point [True]
# 241 Text feature [year] present in test data point [True]
# 242 Text feature [transcription] present in test data point [True]
# 244 Text feature [localization] present in test data point [True]
# 245 Text feature [addition] present in test data point [True]
# 246 Text feature [calculated] present in test data point [True]
# 248 Text feature [higher] present in test data point [True]
# 250 Text feature [known] present in test data point [True]
# 251 Text feature [transfected] present in test data point [True]
# 252 Text feature [use] present in test data point [True]
# 253 Text feature [detection] present in test data point [True]
# 254 Text feature [interaction] present in test data point [True]
# 256 Text feature [absence] present in test data point [True]
# 260 Text feature [64] present in test data point [True]
# 261 Text feature [conserved] present in test data point [True]
# 265 Text feature [soft] present in test data point [True]
# 266 Text feature [potent] present in test data point [True]
# 268 Text feature [3b] present in test data point [True]
# 269 Text feature [initial] present in test data point [True]
# 271 Text feature [available] present in test data point [True]
# 272 Text feature [reduced] present in test data point [True]
# 273 Text feature [technology] present in test data point [True]
# 274 Text feature [day] present in test data point [True]
# 277 Text feature [positive] present in test data point [True]
# 279 Text feature [effects] present in test data point [True]
# 281 Text feature [11] present in test data point [True]
# 282 Text feature [contrast] present in test data point [True]
# 283 Text feature [17] present in test data point [True]
# 284 Text feature [common] present in test data point [True]
# 285 Text feature [sequencing] present in test data point [True]
# 286 Text feature [well] present in test data point [True]
# 287 Text feature [mutants] present in test data point [True]
# 289 Text feature [although] present in test data point [True]
# 291 Text feature [based] present in test data point [True]
# 292 Text feature [enhanced] present in test data point [True]
# 294 Text feature [combined] present in test data point [True]
# 295 Text feature [results] present in test data point [True]
# 296 Text feature [leukemia] present in test data point [True]
# 297 Text feature [vitro] present in test data point [True]
# 298 Text feature [150] present in test data point [True]
# 299 Text feature [clinically] present in test data point [True]
# 301 Text feature [administration] present in test data point [True]
# 302 Text feature [anti] present in test data point [True]
# 303 Text feature [tissue] present in test data point [True]
# 307 Text feature [weeks] present in test data point [True]
# 308 Text feature [12] present in test data point [True]
# 309 Text feature [case] present in test data point [True]
# 310 Text feature [culture] present in test data point [True]
# 311 Text feature [point] present in test data point [True]
# 312 Text feature [developed] present in test data point [True]
# 314 Text feature [total] present in test data point [True]
# 316 Text feature [deletion] present in test data point [True]
# 317 Text feature [increased] present in test data point [True]
# 319 Text feature [institutional] present in test data point [True]
# 320 Text feature [vector] present in test data point [True]
# 321 Text feature [15] present in test data point [True]
# 327 Text feature [oncogenes] present in test data point [True]
# 328 Text feature [2b] present in test data point [True]
# 329 Text feature [time] present in test data point [True]
# 330 Text feature [confer] present in test data point [True]
# 331 Text feature [deficient] present in test data point [True]
# 332 Text feature [site] present in test data point [True]
# 334 Text feature [showed] present in test data point [True]
# 336 Text feature [family] present in test data point [True]
# 339 Text feature [31] present in test data point [True]
# 340 Text feature [previously] present in test data point [True]
# 341 Text feature [observed] present in test data point [True]
# 343 Text feature [16] present in test data point [True]
# 345 Text feature [membrane] present in test data point [True]
# 348 Text feature [length] present in test data point [True]
# 350 Text feature [surface] present in test data point [True]
# 351 Text feature [co] present in test data point [True]
# 352 Text feature [small] present in test data point [True]
# 353 Text feature [mutations] present in test data point [True]
# 356 Text feature [cancer] present in test data point [True]
# 357 Text feature [18] present in test data point [True]
# 360 Text feature [system] present in test data point [True]
# 361 Text feature [present] present in test data point [True]
# 364 Text feature [methods] present in test data point [True]
# 366 Text feature [79] present in test data point [True]
# 370 Text feature [21] present in test data point [True]
# 371 Text feature [per] present in test data point [True]
# 374 Text feature [full] present in test data point [True]
# 375 Text feature [catalytic] present in test data point [True]
# 376 Text feature [malignant] present in test data point [True]
# 377 Text feature [reported] present in test data point [True]
# 380 Text feature [group] present in test data point [True]
# 381 Text feature [resulting] present in test data point [True]
# 382 Text feature [106] present in test data point [True]
# 384 Text feature [specific] present in test data point [True]
# 387 Text feature [cultured] present in test data point [True]
# 389 Text feature [substitution] present in test data point [True]
# 391 Text feature [degradation] present in test data point [True]
# 392 Text feature [yielded] present in test data point [True]
# 395 Text feature [may] present in test data point [True]
# 397 Text feature [three] present in test data point [True]
# 398 Text feature [old] present in test data point [True]
# 399 Text feature [13] present in test data point [True]
# 400 Text feature [genetic] present in test data point [True]
# 402 Text feature [figure] present in test data point [True]
# 404 Text feature [structure] present in test data point [True]
# 406 Text feature [genes] present in test data point [True]
# 408 Text feature [human] present in test data point [True]
# 409 Text feature [genomic] present in test data point [True]
# 411 Text feature [highly] present in test data point [True]
# 412 Text feature [homozygous] present in test data point [True]
# 414 Text feature [define] present in test data point [True]
# 415 Text feature [et] present in test data point [True]
# 416 Text feature [shown] present in test data point [True]
# 417 Text feature [identified] present in test data point [True]
# 418 Text feature [murine] present in test data point [True]
# 419 Text feature [refractory] present in test data point [True]
# 420 Text feature [33] present in test data point [True]
# 421 Text feature [defined] present in test data point [True]
# 422 Text feature [amino] present in test data point [True]
# 423 Text feature [nih] present in test data point [True]
# 425 Text feature [29] present in test data point [True]
# 428 Text feature [demonstrated] present in test data point [True]
# 429 Text feature [effect] present in test data point [True]
# 430 Text feature [putative] present in test data point [True]
# 432 Text feature [fig] present in test data point [True]
# 433 Text feature [domains] present in test data point [True]
# 435 Text feature [leading] present in test data point [True]
# 436 Text feature [acid] present in test data point [True]
# 438 Text feature [practice] present in test data point [True]
# 439 Text feature [molecule] present in test data point [True]
# 441 Text feature [gene] present in test data point [True]
# 442 Text feature [injection] present in test data point [True]
# 444 Text feature [table] present in test data point [True]
# 448 Text feature [different] present in test data point [True]
# 450 Text feature [models] present in test data point [True]
# 452 Text feature [control] present in test data point [True]
# 453 Text feature [discussion] present in test data point [True]
# 455 Text feature [expressed] present in test data point [True]
# 457 Text feature [76] present in test data point [True]
# 460 Text feature [significant] present in test data point [True]
# 461 Text feature [line] present in test data point [True]
# 462 Text feature [studies] present in test data point [True]
# 463 Text feature [mechanism] present in test data point [True]
# 464 Text feature [targets] present in test data point [True]
# 466 Text feature [multiple] present in test data point [True]
# 467 Text feature [amount] present in test data point [True]
# 468 Text feature [interact] present in test data point [True]
# 469 Text feature [event] present in test data point [True]
# 470 Text feature [currently] present in test data point [True]
# 471 Text feature [somatic] present in test data point [True]
# 472 Text feature [analysis] present in test data point [True]
# 474 Text feature [according] present in test data point [True]
# 475 Text feature [within] present in test data point [True]
# 476 Text feature [27] present in test data point [True]
# 478 Text feature [compared] present in test data point [True]
# 479 Text feature [report] present in test data point [True]
# 482 Text feature [many] present in test data point [True]
# 483 Text feature [10] present in test data point [True]
# 484 Text feature [two] present in test data point [True]
# 486 Text feature [among] present in test data point [True]
# 488 Text feature [19] present in test data point [True]
# 489 Text feature [levels] present in test data point [True]
# 491 Text feature [region] present in test data point [True]
# 493 Text feature [majority] present in test data point [True]
# 495 Text feature [important] present in test data point [True]
# 498 Text feature [role] present in test data point [True]
# 500 Text feature [obtained] present in test data point [True]
# 502 Text feature [vehicle] present in test data point [True]
# 506 Text feature [involved] present in test data point [True]
# 508 Text feature [respectively] present in test data point [True]
# 510 Text feature [gain] present in test data point [True]
# 511 Text feature [significantly] present in test data point [True]
# 512 Text feature [ml] present in test data point [True]
# 513 Text feature [pcr] present in test data point [True]
# 514 Text feature [without] present in test data point [True]
# 515 Text feature [3a] present in test data point [True]
# 517 Text feature [western] present in test data point [True]
# 520 Text feature [examined] present in test data point [True]
# 522 Text feature [phosphatidylinositol] present in test data point [True]
# 523 Text feature [distribution] present in test data point [True]
# 524 Text feature [significance] present in test data point [True]
# 529 Text feature [tested] present in test data point [True]
# 530 Text feature [including] present in test data point [True]
# 531 Text feature [20] present in test data point [True]
# 532 Text feature [germline] present in test data point [True]
# 536 Text feature [identify] present in test data point [True]
# 537 Text feature [medium] present in test data point [True]
# 538 Text feature [remains] present in test data point [True]
# 540 Text feature [described] present in test data point [True]
# 541 Text feature [next] present in test data point [True]
# 542 Text feature [several] present in test data point [True]
# 543 Text feature [28] present in test data point [True]
# 544 Text feature [mutated] present in test data point [True]
# 545 Text feature [residues] present in test data point [True]
# 546 Text feature [suggest] present in test data point [True]
# 548 Text feature [indicated] present in test data point [True]
# 549 Text feature [number] present in test data point [True]
# 550 Text feature [inhibit] present in test data point [True]
# 551 Text feature [immunoblotting] present in test data point [True]
# 552 Text feature [set] present in test data point [True]
# 553 Text feature [individuals] present in test data point [True]
# 554 Text feature [would] present in test data point [True]
# 556 Text feature [revealed] present in test data point [True]
# 560 Text feature [half] present in test data point [True]
# 561 Text feature [63] present in test data point [True]
# 563 Text feature [animal] present in test data point [True]
# 564 Text feature [determine] present in test data point [True]
# 567 Text feature [agar] present in test data point [True]
# 568 Text feature [22] present in test data point [True]
# 569 Text feature [occur] present in test data point [True]
# 570 Text feature [reporter] present in test data point [True]
# 571 Text feature [43] present in test data point [True]
# 573 Text feature [close] present in test data point [True]
# 574 Text feature [1a] present in test data point [True]
# 575 Text feature [24] present in test data point [True]
# 576 Text feature [new] present in test data point [True]
# 577 Text feature [consistent] present in test data point [True]
# 579 Text feature [members] present in test data point [True]
# 580 Text feature [however] present in test data point [True]
# 581 Text feature [corresponding] present in test data point [True]
# 582 Text feature [increasing] present in test data point [True]
# 583 Text feature [dependent] present in test data point [True]
# 584 Text feature [model] present in test data point [True]
# 585 Text feature [critical] present in test data point [True]
# 587 Text feature [sequenced] present in test data point [True]
# 589 Text feature [nucleus] present in test data point [True]
# 590 Text feature [cancers] present in test data point [True]
# 591 Text feature [suggesting] present in test data point [True]
# 593 Text feature [whether] present in test data point [True]
# 594 Text feature [regions] present in test data point [True]
# 595 Text feature [still] present in test data point [True]
# 597 Text feature [approach] present in test data point [True]
# 598 Text feature [wt] present in test data point [True]
# 602 Text feature [generated] present in test data point [True]
# 603 Text feature [studied] present in test data point [True]
# 604 Text feature [chromosome] present in test data point [True]
# 605 Text feature [whereas] present in test data point [True]
# 606 Text feature [development] present in test data point [True]
# 607 Text feature [mice] present in test data point [True]
# 610 Text feature [included] present in test data point [True]
# 611 Text feature [population] present in test data point [True]
# 613 Text feature [include] present in test data point [True]
# 614 Text feature [structural] present in test data point [True]
# 615 Text feature [single] present in test data point [True]
# 616 Text feature [loop] present in test data point [True]
# 617 Text feature [found] present in test data point [True]
# 618 Text feature [vivo] present in test data point [True]
# 620 Text feature [23] present in test data point [True]
# 622 Text feature [36] present in test data point [True]
# 623 Text feature [across] present in test data point [True]
# 627 Text feature [otherwise] present in test data point [True]
# 629 Text feature [negative] present in test data point [True]
# 631 Text feature [level] present in test data point [True]
# 632 Text feature [regulation] present in test data point [True]
# 633 Text feature [signal] present in test data point [True]
# 635 Text feature [furthermore] present in test data point [True]
# 636 Text feature [phase] present in test data point [True]
# 638 Text feature [induced] present in test data point [True]
# 639 Text feature [viral] present in test data point [True]
# 640 Text feature [increase] present in test data point [True]
# 642 Text feature [difference] present in test data point [True]
# 644 Text feature [mutation] present in test data point [True]
# 645 Text feature [fold] present in test data point [True]
# 646 Text feature [might] present in test data point [True]
# 647 Text feature [introduction] present in test data point [True]
# 648 Text feature [50] present in test data point [True]
# 650 Text feature [53] present in test data point [True]
# 652 Text feature [part] present in test data point [True]
# 654 Text feature [status] present in test data point [True]
# 655 Text feature [performed] present in test data point [True]
# 657 Text feature [dimerization] present in test data point [True]
# 660 Text feature [occurrence] present in test data point [True]
# 661 Text feature [together] present in test data point [True]
# 663 Text feature [also] present in test data point [True]
# 666 Text feature [could] present in test data point [True]
# 668 Text feature [sites] present in test data point [True]
# 669 Text feature [3e] present in test data point [True]
# 670 Text feature [lacking] present in test data point [True]
# 671 Text feature [2a] present in test data point [True]
# 672 Text feature [individual] present in test data point [True]
# 673 Text feature [associated] present in test data point [True]
# 674 Text feature [tumor] present in test data point [True]
# 675 Text feature [46] present in test data point [True]
# 677 Text feature [non] present in test data point [True]
# 679 Text feature [characterized] present in test data point [True]
# 681 Text feature [mouse] present in test data point [True]
# 682 Text feature [complex] present in test data point [True]
# 685 Text feature [lower] present in test data point [True]
# 686 Text feature [32] present in test data point [True]
# 687 Text feature [confirmed] present in test data point [True]
# 688 Text feature [using] present in test data point [True]
# 690 Text feature [due] present in test data point [True]
# 691 Text feature [partially] present in test data point [True]
# 692 Text feature [96] present in test data point [True]
# 695 Text feature [high] present in test data point [True]
# 696 Text feature [residue] present in test data point [True]
# 699 Text feature [thus] present in test data point [True]
# 700 Text feature [samples] present in test data point [True]
# 701 Text feature [values] present in test data point [True]
# 702 Text feature [exon] present in test data point [True]
# 703 Text feature [rearrangements] present in test data point [True]
# 704 Text feature [antibody] present in test data point [True]
# 705 Text feature [coding] present in test data point [True]
# 706 Text feature [phosphotyrosine] present in test data point [True]
# 709 Text feature [65] present in test data point [True]
# 710 Text feature [dominant] present in test data point [True]
# 711 Text feature [standard] present in test data point [True]
# 712 Text feature [seen] present in test data point [True]
# 715 Text feature [target] present in test data point [True]
# 718 Text feature [review] present in test data point [True]
# 719 Text feature [encoding] present in test data point [True]
# 720 Text feature [position] present in test data point [True]
# 722 Text feature [disease] present in test data point [True]
# 723 Text feature [s3] present in test data point [True]
# 727 Text feature [25] present in test data point [True]
# 730 Text feature [provide] present in test data point [True]
# 731 Text feature [adenocarcinoma] present in test data point [True]
# 732 Text feature [30] present in test data point [True]
# 734 Text feature [44] present in test data point [True]
# 735 Text feature [alterations] present in test data point [True]
# 737 Text feature [variation] present in test data point [True]
# 738 Text feature [normal] present in test data point [True]
# 739 Text feature [interactions] present in test data point [True]
# 741 Text feature [conversely] present in test data point [True]
# 742 Text feature [transactivation] present in test data point [True]
# 743 Text feature [paraffin] present in test data point [True]
# 745 Text feature [selected] present in test data point [True]
# 747 Text feature [required] present in test data point [True]
# 748 Text feature [26] present in test data point [True]
# 749 Text feature [pathology] present in test data point [True]
# 751 Text feature [focused] present in test data point [True]
# 753 Text feature [interestingly] present in test data point [True]
# 755 Text feature [algorithm] present in test data point [True]
# 756 Text feature [lysates] present in test data point [True]
# 757 Text feature [approaches] present in test data point [True]
# 759 Text feature [60] present in test data point [True]
# 762 Text feature [000] present in test data point [True]
# 764 Text feature [discovery] present in test data point [True]
# 766 Text feature [basal] present in test data point [True]
# 767 Text feature [70] present in test data point [True]
# 768 Text feature [analyzed] present in test data point [True]
# 769 Text feature [exonic] present in test data point [True]
# 770 Text feature [al] present in test data point [True]
# 775 Text feature [measured] present in test data point [True]
# 777 Text feature [contribute] present in test data point [True]
# 778 Text feature [1b] present in test data point [True]
# 781 Text feature [determined] present in test data point [True]
# 782 Text feature [either] present in test data point [True]
# 785 Text feature [factors] present in test data point [True]
# 786 Text feature [fully] present in test data point [True]
# 790 Text feature [investigated] present in test data point [True]
# 792 Text feature [result] present in test data point [True]
# 793 Text feature [genetics] present in test data point [True]
# 795 Text feature [mediated] present in test data point [True]
# 798 Text feature [selective] present in test data point [True]
# 799 Text feature [similar] present in test data point [True]
# 800 Text feature [rate] present in test data point [True]
# 801 Text feature [note] present in test data point [True]
# 802 Text feature [leads] present in test data point [True]
# 803 Text feature [targeted] present in test data point [True]
# 804 Text feature [related] present in test data point [True]
# 805 Text feature [need] present in test data point [True]
# 806 Text feature [fact] present in test data point [True]
# 807 Text feature [screening] present in test data point [True]
# 808 Text feature [less] present in test data point [True]
# 810 Text feature [signals] present in test data point [True]
# 811 Text feature [lack] present in test data point [True]
# 814 Text feature [second] present in test data point [True]
# 816 Text feature [generation] present in test data point [True]
# 818 Text feature [overall] present in test data point [True]
# 820 Text feature [transfection] present in test data point [True]
# 821 Text feature [free] present in test data point [True]
# 822 Text feature [appears] present in test data point [True]
# 824 Text feature [detected] present in test data point [True]
# 825 Text feature [rather] present in test data point [True]
# 826 Text feature [rna] present in test data point [True]
# 829 Text feature [unlike] present in test data point [True]
# 830 Text feature [none] present in test data point [True]
# 831 Text feature [cases] present in test data point [True]
# 835 Text feature [37] present in test data point [True]
# 836 Text feature [frequently] present in test data point [True]
# 838 Text feature [article] present in test data point [True]
# 839 Text feature [sequences] present in test data point [True]
# 840 Text feature [rescue] present in test data point [True]
# 842 Text feature [panel] present in test data point [True]
# 843 Text feature [five] present in test data point [True]
# 844 Text feature [typically] present in test data point [True]
# 845 Text feature [first] present in test data point [True]
# 846 Text feature [test] present in test data point [True]
# 849 Text feature [unknown] present in test data point [True]
# 852 Text feature [applied] present in test data point [True]
# 853 Text feature [major] present in test data point [True]
# 854 Text feature [plates] present in test data point [True]
# 855 Text feature [types] present in test data point [True]
# 856 Text feature [distinct] present in test data point [True]
# 857 Text feature [changes] present in test data point [True]
# 858 Text feature [35] present in test data point [True]
# 859 Text feature [moreover] present in test data point [True]
# 860 Text feature [years] present in test data point [True]
# 861 Text feature [100] present in test data point [True]
# 870 Text feature [hypothesis] present in test data point [True]
# 871 Text feature [even] present in test data point [True]
# 872 Text feature [change] present in test data point [True]
# 873 Text feature [2c] present in test data point [True]
# 879 Text feature [evaluate] present in test data point [True]
# 880 Text feature [knockout] present in test data point [True]
# 882 Text feature [blue] present in test data point [True]
# 884 Text feature [better] present in test data point [True]
# 885 Text feature [39] present in test data point [True]
# 887 Text feature [form] present in test data point [True]
# 889 Text feature [correspond] present in test data point [True]
# 892 Text feature [led] present in test data point [True]
# 894 Text feature [basis] present in test data point [True]
# 895 Text feature [mm] present in test data point [True]
# 896 Text feature [grew] present in test data point [True]
# 897 Text feature [representative] present in test data point [True]
# 899 Text feature [presented] present in test data point [True]
# 900 Text feature [four] present in test data point [True]
# 901 Text feature [located] present in test data point [True]
# 902 Text feature [show] present in test data point [True]
# 903 Text feature [outcome] present in test data point [True]
# 904 Text feature [mean] present in test data point [True]
# 906 Text feature [whole] present in test data point [True]
# 907 Text feature [provides] present in test data point [True]
# 908 Text feature [injected] present in test data point [True]
# 910 Text feature [previous] present in test data point [True]
# 911 Text feature [direct] present in test data point [True]
# 912 Text feature [carrying] present in test data point [True]
# 914 Text feature [value] present in test data point [True]
# 915 Text feature [directly] present in test data point [True]
# 919 Text feature [low] present in test data point [True]
# 920 Text feature [findings] present in test data point [True]
# 921 Text feature [require] present in test data point [True]
# 922 Text feature [mutational] present in test data point [True]
# 924 Text feature [allele] present in test data point [True]
# 925 Text feature [45] present in test data point [True]
# 926 Text feature [support] present in test data point [True]
# 927 Text feature [research] present in test data point [True]
# 928 Text feature [assess] present in test data point [True]
# 930 Text feature [genome] present in test data point [True]
# 938 Text feature [fraction] present in test data point [True]
# 941 Text feature [ii] present in test data point [True]
# 942 Text feature [followed] present in test data point [True]
# 943 Text feature [reverse] present in test data point [True]
# 944 Text feature [evaluated] present in test data point [True]
# 945 Text feature [current] present in test data point [True]
# 947 Text feature [deleted] present in test data point [True]
# 948 Text feature [groups] present in test data point [True]
# 949 Text feature [remaining] present in test data point [True]
# 950 Text feature [subset] present in test data point [True]
# 953 Text feature [components] present in test data point [True]
# 958 Text feature [chemotherapy] present in test data point [True]
# 959 Text feature [derived] present in test data point [True]
# 960 Text feature [provided] present in test data point [True]
# 961 Text feature [made] present in test data point [True]
# 963 Text feature [versus] present in test data point [True]
# 964 Text feature [address] present in test data point [True]
# 967 Text feature [mechanisms] present in test data point [True]
# 968 Text feature [isolated] present in test data point [True]
# 969 Text feature [transduction] present in test data point [True]
# 975 Text feature [displayed] present in test data point [True]
# 978 Text feature [suggests] present in test data point [True]
# 980 Text feature [acids] present in test data point [True]
# 982 Text feature [forms] present in test data point [True]
# 985 Text feature [additional] present in test data point [True]
# 986 Text feature [differences] present in test data point [True]
# 988 Text feature [top] present in test data point [True]
# 989 Text feature [transcript] present in test data point [True]
# 992 Text feature [34] present in test data point [True]
# 995 Text feature [institute] present in test data point [True]
# 996 Text feature [strong] present in test data point [True]
# 998 Text feature [reference] present in test data point [True]
# 999 Text feature [concentration] present in test data point [True]
# Out of the top  1000  features  610 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', 
      alpha[int(best_alpha/4)], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', 
      alpha[int(best_alpha/4)], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', 
      alpha[int(best_alpha/4)], 
      "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 1.9151191022023135
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.5880462468475758
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.3902022303575985
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.821788210225227
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.5905075468409895
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.3290156602415986
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.3818069848094703
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.5883799368023446
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5376894663724567
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.376461698586797
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.3265199288193557
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.5708753260366766
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.533701965573669
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.3965157997402604
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3472800079830147
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.5900550609206183
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.5434297777209514
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.462747260276
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.350622287056004
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.60353706137819
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.5298757719558218
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.4734256831046868
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3318587399207393
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.5899282494127234
# For values of best alpha =  100 The train log loss is: 0.07658555232515298
# For values of best alpha =  100 The cross validation log loss is: 1.3265199288193557
# For values of best alpha =  100 The test log loss is: 1.4369035718420244

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3265199288193557
# Number of mis-classified points : 0.4813753581661891
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 20
no_feature = 1000
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
# indices = np.argsort(-clf.feature_importances_)
# print("-"*50)
# for i in indices:
#     if i<9:
#         print("Gene is important feature")
#     elif i<18:
#         print("Variation is important feature")
#     else:
#         print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0208 0.4418 0.1211 0.0207 0.0478 0.0608 0.2407 0.029  0.0173]]
# Actual Class : 2

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 31
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
# indices = np.argsort(-clf.feature_importances_)
# print("-"*50)
# for i in indices:
#     if i<9:
#         print("Gene is important feature")
#     elif i<18:
#         print("Variation is important feature")
#     else:
#         print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0035 0.0079 0.0031 0.0044 0.0027 0.0052 0.9675 0.0032 0.0026]]
# Actual Class : 7

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.01, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=1000)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.03
# Support vector machines : Log Loss: 1.12
# Naive Bayes : Log Loss: 1.19
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 1.820
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.710
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.296
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.136
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.339
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.699

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.46499715339025904
# Log loss (CV) on the stacking classifier : 1.1359385939127755
# Log loss (test) on the stacking classifier : 1.2329997994311812
# Number of missclassified point : 0.4102306920762287
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.6319554931728159
# Log loss (CV) on the VotingClassifier : 1.0375424379393854
# Log loss (test) on the VotingClassifier : 1.1678423871456274
# Number of missclassified point : 0.4102306920762287
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3> Logistic Regression With Class Balancing </h3>

# %% [markdown]
# <b>Gene Feature</b>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1

# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_train))

# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_test))

# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_cv))

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer(ngram_range=(1, 2))
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(x_train['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(x_test['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(x_cv['Gene'])

# don't forget to normalize every feature
train_gene_feature_onehotCoding = normalize(train_gene_feature_onehotCoding, axis=0)
test_gene_feature_onehotCoding = normalize(test_gene_feature_onehotCoding, axis=0)
cv_gene_feature_onehotCoding = normalize(cv_gene_feature_onehotCoding, axis=0)

# %% [markdown]
# <b>Variation Feature</b>

# %%
# alpha is used for laplace smoothing
alpha = 1

# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_train))

# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_test))

# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_cv))

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer(ngram_range=(1, 2))
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(x_train['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(x_test['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(x_cv['Variation'])


# don't forget to normalize every feature
train_variation_feature_onehotCoding = normalize(train_variation_feature_onehotCoding, axis=0)
test_variation_feature_onehotCoding = normalize(test_variation_feature_onehotCoding, axis=0)
cv_variation_feature_onehotCoding = normalize(cv_variation_feature_onehotCoding, axis=0)

# %% [markdown]
# <b>Text Feature</b>

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3,ngram_range=(1, 2))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(x_train['TEXT'])

# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 667216

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(x_train)
test_text_feature_responseCoding  = get_text_responsecoding(x_test)
cv_text_feature_responseCoding  = get_text_responsecoding(x_cv)

# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(x_test['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(x_cv['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %% [markdown]
# <b> Stack above three features </b>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(y_train['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(y_test['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(y_cv['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (1626, 669033)
# (number of data points * number of features) in test data =  (997, 669033)
# (number of data points * number of features) in cross validation data = (698, 669033)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (1626, 27)
# (number of data points * number of features) in test data =  (997, 27)
# (number of data points * number of features) in cross validation data = (698, 27)

# %% [markdown]
# <b> Lets apply Logistic Regression </b>

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.5558798788922188
# for alpha = 1e-05
# Log Loss : 1.5499207477974812
# for alpha = 0.0001
# Log Loss : 1.484676594114223
# for alpha = 0.001
# Log Loss : 1.2144082132352159
# for alpha = 0.01
# Log Loss : 1.1667009184924586
# for alpha = 0.1
# Log Loss : 1.2136763642009278
# for alpha = 1
# Log Loss : 1.3143829019452755
# for alpha = 10
# Log Loss : 1.4035478120583103
# for alpha = 100
# Log Loss : 1.423518825197014
# For values of best alpha =  0.01 The train log loss is: 0.6690454436400668
# For values of best alpha =  0.01 The cross validation log loss is: 1.1667009184924586
# For values of best alpha =  0.01 The test log loss is: 1.2639137878874733

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1667009184924586
# Number of mis-classified points : 0.39255014326647564
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3> Lets apply feature engineering on the data and then apply logistic regression again </h3>

# %% [markdown]
# <b> Lets merge gene and variation data into one list and apply TFidfVectorizer on top of it.</b>

# %% [markdown]
# <b>Gene Feature</b>

# %%
result = pd.merge(data_variants, data_text,on='ID', how='left')
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']
y_true = result['Class'].values
result.Gene = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

x_train, x_test, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)

x_train, x_cv, y_train, y_cv = train_test_split(x_train, y_train, stratify=y_train, test_size=0.2)

# %%
# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    value_count = x_train[feature].value_counts()
    gv_dict = dict()
    for i, denominator in value_count.items():
        vec = []
        for k in range(1,10):
            cls_cnt = x_train.loc[(x_train['Class']==k) & (x_train[feature]==i)]
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    gv_dict = get_gv_fea_dict(alpha, feature, df)   
    value_count = x_train[feature].value_counts()
    gv_fea = []
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
    return gv_fea

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1

# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_train))

# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_test))

# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", x_cv))

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(x_train['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(x_test['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(x_cv['Gene'])

# %% [markdown]
# <b>Variation Feature</b>

# %%
# alpha is used for laplace smoothing
alpha = 1

# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_train))

# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_test))

# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", x_cv))

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(x_train['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(x_test['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(x_cv['Variation'])

# %% [markdown]
# <b>Text Feature</b>

# %%
def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary


import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer()
train_text_feature_onehotCoding = text_vectorizer.fit_transform(x_train['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 123710

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = x_train[x_train['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(x_train)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(x_train)
test_text_feature_responseCoding  = get_text_responsecoding(x_test)
cv_text_feature_responseCoding  = get_text_responsecoding(x_cv)

# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
test_text_feature_onehotCoding = text_vectorizer.transform(x_test['TEXT'])
cv_text_feature_onehotCoding = text_vectorizer.transform(x_cv['TEXT'])

# %% [markdown]
# <b> Features after feature engineering </b>

# %%
# Collecting all the genes and variations data into a single list
gene_variation = []

for gene in data_variants['Gene'].values:
    gene_variation.append(gene)

for variation in data_variants['Variation'].values:
    gene_variation.append(variation)

# %%
tfidfVectorizer = TfidfVectorizer(max_features=1000)
text2 = tfidfVectorizer.fit_transform(gene_variation)
gene_variation_features = tfidfVectorizer.get_feature_names()

train_text = tfidfVectorizer.transform(x_train['TEXT'])
test_text = tfidfVectorizer.transform(x_test['TEXT'])
cv_text = tfidfVectorizer.transform(x_cv['TEXT'])

# %% [markdown]
# <b> Stack above three features </b>

# %%
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

# Adding the train_text feature
train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text))
train_x_onehotCoding = hstack((train_x_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(x_train['Class']))

# Adding the test_text feature
test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text))
test_x_onehotCoding = hstack((test_x_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(x_test['Class']))

# Adding the cv_text feature
cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text))
cv_x_onehotCoding = hstack((cv_x_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(x_cv['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 126912)
# (number of data points * number of features) in test data =  (665, 126912)
# (number of data points * number of features) in cross validation data = (532, 126912)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The train log loss is:",
      log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], 
      "The cross validation log loss is:",
      log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', 
      alpha[best_alpha], "The test log loss is:",
      log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.0629200220019392
# for alpha = 1e-05
# Log Loss : 0.9983856757483809
# for alpha = 0.0001
# Log Loss : 0.9538719325102536
# for alpha = 0.001
# Log Loss : 1.0033344642632218
# for alpha = 0.01
# Log Loss : 1.2328163087959843
# for alpha = 0.1
# Log Loss : 1.6089198184620896
# for alpha = 1
# Log Loss : 1.7193166013870296
# for alpha = 10
# Log Loss : 1.7296416766663751
# for alpha = 100
# Log Loss : 1.7306871920866913
# For values of best alpha =  0.0001 The train log loss is: 0.3910825232132724
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9538719325102536
# For values of best alpha =  0.0001 The test log loss is: 0.9744909002661803

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9538719325102536
# Number of mis-classified points : 0.3233082706766917
#
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
print()
from prettytable import PrettyTable
ptable = PrettyTable()
ptable.title = "*** Model Summary *** [Performance Metric: Log-Loss]"
ptable.field_names=["Model Name","Train","Test"]
ptable.add_row(["Naive Bayes","0.92","1.27"])
ptable.add_row(["KNN","0.687","1.157"])
ptable.add_row(["Logistic Regression With Class balancing","0.481","1.128"])
ptable.add_row(["Logistic Regression Without Class balancing","0.478","1.128"])
ptable.add_row(["Linear SVM","0.522","1.222"])
ptable.add_row(["Random Forest Classifier With One hot Encoding","0.583","1.173"])
ptable.add_row(["Random Forest Classifier With Response Coding","0.076","1.436"])
ptable.add_row(["Stack Models:LR+NB+SVM","0.464","1.232"])
ptable.add_row(["Maximum Voting classifier","0.6","1.16"])
ptable.add_row(["LOGISTIC REGRESSION WITH FEATURE ENGINEERING","0.391","0.974"])
print(ptable)
print()
# Out:
# +------------------------------------------------+-------+-------+
# |                   Model Name                   | Train |  Test |
# +------------------------------------------------+-------+-------+
# |                  Naive Bayes                   |  0.92 |  1.27 |
# |                      KNN                       | 0.687 | 1.157 |
# |    Logistic Regression With Class balancing    | 0.481 | 1.128 |
# |  Logistic Regression Without Class balancing   | 0.478 | 1.128 |
# |                   Linear SVM                   | 0.522 | 1.222 |
# | Random Forest Classifier With One hot Encoding | 0.583 | 1.173 |
# | Random Forest Classifier With Response Coding  | 0.076 | 1.436 |
# |             Stack Models:LR+NB+SVM             | 0.464 | 1.232 |
# |           Maximum Voting classifier            |  0.6  |  1.16 |
# |  LOGISTIC REGRESSION WITH FEATURE ENGINEERING  | 0.391 | 0.974 |
# +------------------------------------------------+-------+-------+

# %% [markdown]
# ### Conclusion:
# <b> After some feature engineering I manage to decrease the log loss below < 1 i.e 0.95
